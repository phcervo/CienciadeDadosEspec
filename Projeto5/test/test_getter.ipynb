# %% [markdown]
# # Módulo de busca de página- getter

# %% [markdown]
# ## Função get_web
# Está função provê uma função  de buscar páginas na web com a seguinte assinatura.

# %%
# Função get_web
from typing import Any
def get_web(nome_pagina: str) -> Any:
    """ Está função busca páginas na web""" 
    pass

# %% [markdown]
# #  Treinando o uso da biblioteca Requests
# A referência está [aqui(https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
import requests

# %%
# Buscar dados no site
r = requests.get('https://api.github.com/events')
print(type(r))
# Out:
# <class 'requests.models.Response'>

# %%
# Enviar informações e gravar dados
r = requests.post('https://httpbin.org/post', data={'key': 'value'})
print(type(r))
# Out:
# <class 'requests.models.Response'>

# %%
# Conteúdo da resposta
## Podemos ler o conteúdo da resposta do servidor

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"33981158451","type":"PushEvent","actor":{"id":137444422,"login":"MartiZu","display_login":"MartiZu","gravatar_id":"","url":"https://api.github.com/users/MartiZu","avatar_url":"https://avatars.githubusercontent.com/u/137444422?"},"repo":{"id":727267623,"name":"MartiZu/LandLogic-app","url":"https://api.github.com/repos/MartiZu/LandLogic-app"},"payload":{"repository_id":727267623,"push_id":16175095488,"size":2,"distinct_size":1,"ref":"refs/heads/main","head":"3bb01610e765b74efa44c5e68db54586fefc8e68","before":"3bc141c441a2e37d04eecad217ee01923d3f9dee","commits":[{"sha":"992c0f861b3f190f9e6e96701944a794f916ef97","author":{"email":"adam.hale92@googlemail.com","name":"Adam Hale"},"message":"wrote logic for remortgage tool button, removed card styling from remortgage tool","distinct":false,"url":"https://api.github.com/repos/MartiZu/LandLogic-app/commits/992c0f861b3f190f9e6e96701944a794f916ef97"},{"sha":"3bb01610e765b74efa44c5e68db54586fefc8e68","author":{"email":"137444422+MartiZu@users.noreply.github.com","name":"Martina Zurli"},"message":"Merge pull request #13 from MartiZu/background\\n\\nwrote logic for remortgage tool button, removed card styling from rem…","distinct":true,"url":"https://api.github.com/repos/MartiZu/LandLogic-app/commits/3bb01610e765b74efa44c5e68db54586fefc8e68"}]},"public":true,"created_at":"2023-12-07T14:35:17Z"},{"id":"33981158421","type":"PullRequestEvent","actor":{"id":51692363,"login":"gunom","display_login":"gunom","gravatar_id":"","url":"https://api.github.com/users/gunom","avatar_url":"https://avatars.githubusercontent.com/u/51692363?"},"repo":{"id":539013867,"name":"sopt-makers/sopt-backend","url":"https://api.github.com/repos/sopt-makers/sopt-backend"},"payload":{"action":"closed","number":163,"pull_request":{"url":"https://api.github.com/repos/sopt-makers/sopt-backend/pulls/163","id":1634509977,"node_id":"PR_kwDOICCy685hbKSZ","html_url":"https://github.com/sopt-makers/sopt-backend/pull/163","diff_url":"https://github.com/sopt-makers/sopt-backend/pull/163.diff","patch_url":"https://github.com/sopt-makers/sopt-backend/pull/163.patch","issue_url":"https://api.github.com/repos/sopt-makers/sopt-backend/issues/163","number":163,"state":"closed","locked":false,"title":"Feat/#154 friends friend recommend","user":{"login":"gunom","id":51692363,"node_id":"MDQ6VXNlcjUxNjkyMzYz","avatar_url":"https://avatars.githubusercontent.com/u/51692363?v=4","gravatar_id":"","url":"https://api.github.com/users/gunom","html_url":"https://github.com/gunom","followers_url":"https://api.github.com/users/gunom/followers","following_url":"https://api.github.com/users/gunom/following{/other_user}","gists_url":"https://api.github.com/users/gunom/gists{/gist_id}","starred_url":"https://api.github.com/users/gunom/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/gunom/subscriptions","organizations_url":"https://api.github.com/users/gunom/orgs","repos_url":"https://api.github.com/users/gunom/repos","events_url":"https://api.github.com/users/gunom/events{/privacy}","received_events_url":"https://api.github.com/users/gunom/received_events","type":"User","site_admin":false},"body":"## 📝 PR Summary\\r\\n친구의 친구를 추천하는 API를 QueryDSL을 사용해서 만들었습니다.\\r\\n그러나 비즈니스 로직이 너무 깊게 QueryDSL로 만든거 같아서 이걸 조금 수정하고 싶은데 다음 리팩토링때 가져갈 예정입니다.\\r\\n\\r\\n#### 🌵 Working Branch\\r\\nfeat/#154-friends-friend-recommend\\r\\n\\r\\n#### 🌴 Works\\r\\n- [ ]\\r\\n- [ ]\\r\\n\\r\\n\\r\\n#### 🌱 Related Issue\\r\\n\\r\\n","created_at":"2023-12-07T13:41:26Z","updated_at":"2023-12-07T14:35:16Z","closed_at":"2023-12-07T14:35:16Z","merged_at":"2023-12-07T14:35:16Z","merge_commit_sha":"aee1a59b4b1e71ae0cab657d83b84b525e361d05","assignee":{"login":"gunom","id":51692363,"node_id":"MDQ6VXNlcjUxNjkyMzYz","avatar_url":"https://avatars.githubusercontent.com/u/51692363?v=4","gravatar_id":"","url":"https://api.github.com/users/gunom","html_url":"https://github.com/gunom","followers_url":"https://api.github.com/users/gunom/followers","following_url":"https ...

# %%
# Serve para descobrir a codificação 
r.encoding
# Out:
# 'utf-8'

# %%
r.encoding = 'ISO-8859-1'

# %%
# Conteúdo de resposta binária

# %%
r.content
# Out:
# b'[{"id":"33981158451","type":"PushEvent","actor":{"id":137444422,"login":"MartiZu","display_login":"MartiZu","gravatar_id":"","url":"https://api.github.com/users/MartiZu","avatar_url":"https://avatars.githubusercontent.com/u/137444422?"},"repo":{"id":727267623,"name":"MartiZu/LandLogic-app","url":"https://api.github.com/repos/MartiZu/LandLogic-app"},"payload":{"repository_id":727267623,"push_id":16175095488,"size":2,"distinct_size":1,"ref":"refs/heads/main","head":"3bb01610e765b74efa44c5e68db54586fefc8e68","before":"3bc141c441a2e37d04eecad217ee01923d3f9dee","commits":[{"sha":"992c0f861b3f190f9e6e96701944a794f916ef97","author":{"email":"adam.hale92@googlemail.com","name":"Adam Hale"},"message":"wrote logic for remortgage tool button, removed card styling from remortgage tool","distinct":false,"url":"https://api.github.com/repos/MartiZu/LandLogic-app/commits/992c0f861b3f190f9e6e96701944a794f916ef97"},{"sha":"3bb01610e765b74efa44c5e68db54586fefc8e68","author":{"email":"137444422+MartiZu@users.noreply.github.com","name":"Martina Zurli"},"message":"Merge pull request #13 from MartiZu/background\\n\\nwrote logic for remortgage tool button, removed card styling from rem\xe2\x80\xa6","distinct":true,"url":"https://api.github.com/repos/MartiZu/LandLogic-app/commits/3bb01610e765b74efa44c5e68db54586fefc8e68"}]},"public":true,"created_at":"2023-12-07T14:35:17Z"},{"id":"33981158421","type":"PullRequestEvent","actor":{"id":51692363,"login":"gunom","display_login":"gunom","gravatar_id":"","url":"https://api.github.com/users/gunom","avatar_url":"https://avatars.githubusercontent.com/u/51692363?"},"repo":{"id":539013867,"name":"sopt-makers/sopt-backend","url":"https://api.github.com/repos/sopt-makers/sopt-backend"},"payload":{"action":"closed","number":163,"pull_request":{"url":"https://api.github.com/repos/sopt-makers/sopt-backend/pulls/163","id":1634509977,"node_id":"PR_kwDOICCy685hbKSZ","html_url":"https://github.com/sopt-makers/sopt-backend/pull/163","diff_url":"https://github.com/sopt-makers/sopt-backend/pull/163.diff","patch_url":"https://github.com/sopt-makers/sopt-backend/pull/163.patch","issue_url":"https://api.github.com/repos/sopt-makers/sopt-backend/issues/163","number":163,"state":"closed","locked":false,"title":"Feat/#154 friends friend recommend","user":{"login":"gunom","id":51692363,"node_id":"MDQ6VXNlcjUxNjkyMzYz","avatar_url":"https://avatars.githubusercontent.com/u/51692363?v=4","gravatar_id":"","url":"https://api.github.com/users/gunom","html_url":"https://github.com/gunom","followers_url":"https://api.github.com/users/gunom/followers","following_url":"https://api.github.com/users/gunom/following{/other_user}","gists_url":"https://api.github.com/users/gunom/gists{/gist_id}","starred_url":"https://api.github.com/users/gunom/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/gunom/subscriptions","organizations_url":"https://api.github.com/users/gunom/orgs","repos_url":"https://api.github.com/users/gunom/repos","events_url":"https://api.github.com/users/gunom/events{/privacy}","received_events_url":"https://api.github.com/users/gunom/received_events","type":"User","site_admin":false},"body":"## \xf0\x9f\x93\x9d PR Summary\\r\\n\xec\xb9\x9c\xea\xb5\xac\xec\x9d\x98 \xec\xb9\x9c\xea\xb5\xac\xeb\xa5\xbc \xec\xb6\x94\xec\xb2\x9c\xed\x95\x98\xeb\x8a\x94 API\xeb\xa5\xbc QueryDSL\xec\x9d\x84 \xec\x82\xac\xec\x9a\xa9\xed\x95\xb4\xec\x84\x9c \xeb\xa7\x8c\xeb\x93\xa4\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4.\\r\\n\xea\xb7\xb8\xeb\x9f\xac\xeb\x82\x98 \xeb\xb9\x84\xec\xa6\x88\xeb\x8b\x88\xec\x8a\xa4 \xeb\xa1\x9c\xec\xa7\x81\xec\x9d\xb4 \xeb\x84\x88\xeb\xac\xb4 \xea\xb9\x8a\xea\xb2\x8c QueryDSL\xeb\xa1\x9c \xeb\xa7\x8c\xeb\x93\xa0\xea\xb1\xb0 \xea\xb0\x99\xec\x95\x84\xec\x84\x9c \xec\x9d\xb4\xea\xb1\xb8 \xec\xa1\xb0\xea\xb8\x88 \xec\x88\x98\xec\xa0\x95\xed\x95\x98\xea\xb3\xa0 \xec\x8b\xb6\xec\x9d\x80\xeb\x8d\xb0 \xeb\x8b\xa4\xec\x9d\x8c \xeb\xa6\xac\xed\x8c\xa9\xed\x86\xa0\xeb\xa7\x81\xeb\x95\x8c \xea\xb0\x80\ ...

# %%
# Criar uma imagem a partir de dados binários retornados por uma solicitação

# %%
from PIL import Image
from io import BytesIO

i = Image.open(BytesIO(r.content))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[24], line 4
#       1 from PIL import Image
#       2 from io import BytesIO
# ----> 4 i = Image.open(BytesIO(r.content))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\PIL\Image.py:3283, in open(fp, mode, formats)
#    3281     warnings.warn(message)
#    3282 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3283 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000020768CFFF60>

# %%
# Conteúdo de resposta JSON
## Possui também um decodificador JSON interno.
import requests
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '33981469325',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 16239342,
#    'login': 'pyup-bot',
#    'display_login': 'pyup-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pyup-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16239342?'},
#   'repo': {'id': 103130345,
#    'name': 'SekouD/lyricsmaster',
#    'url': 'https://api.github.com/repos/SekouD/lyricsmaster'},
#   'payload': {'action': 'closed',
#    'number': 1549,
#    'pull_request': {'url': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls/1549',
#     'id': 1632650325,
#     'node_id': 'PR_kwDOBiWk6c5hUERV',
#     'html_url': 'https://github.com/SekouD/lyricsmaster/pull/1549',
#     'diff_url': 'https://github.com/SekouD/lyricsmaster/pull/1549.diff',
#     'patch_url': 'https://github.com/SekouD/lyricsmaster/pull/1549.patch',
#     'issue_url': 'https://api.github.com/repos/SekouD/lyricsmaster/issues/1549',
#     'number': 1549,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Scheduled daily dependency update on Wednesday',
#     'user': {'login': 'pyup-bot',
#      'id': 16239342,
#      'node_id': 'MDQ6VXNlcjE2MjM5MzQy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/16239342?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pyup-bot',
#      'html_url': 'https://github.com/pyup-bot',
#      'followers_url': 'https://api.github.com/users/pyup-bot/followers',
#      'following_url': 'https://api.github.com/users/pyup-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pyup-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pyup-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pyup-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pyup-bot/orgs',
#      'repos_url': 'https://api.github.com/users/pyup-bot/repos',
#      'events_url': 'https://api.github.com/users/pyup-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pyup-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '\n\n\n\n\n### Update [urllib3[secure]](https://pypi.org/project/urllib3) from **1.25.2** to **2.1.0**.\n\n\n<details>\n  <summary>Changelog</summary>\n  \n  \n   ### 2.1.0\n   ```\n   ==================\n\nRead the `v2 migration guide &lt;https://urllib3.readthedocs.io/en/latest/v2-migration-guide.html&gt;`__ for help upgrading to the latest version of urllib3.\n\nRemovals\n--------\n\n- Removed support for the deprecated urllib3[secure] extra. (`2680 &lt;https://github.com/urllib3/urllib3/issues/2680&gt;`__)\n- Removed support for the deprecated SecureTransport TLS implementation. (`2681 &lt;https://github.com/urllib3/urllib3/issues/2681&gt;`__)\n- Removed support for the end-of-life Python 3.7. (`3143 &lt;https://github.com/urllib3/urllib3/issues/3143&gt;`__)\n\n\nBugfixes\n--------\n\n- Allowed loading CA certificates from memory for proxies. (`3065 &lt;https://github.com/urllib3/urllib3/issues/3065&gt;`__)\n- Fixed decoding Gzip-encoded responses which specified ``x-gzip`` content-encoding. (`3174 &lt;https://github.com/urllib3/urllib3/issues/3174&gt;`__)\n   ```\n   \n  \n  \n   ### 2.0.7\n   ```\n   ==================\n\n* Made body stripped from HTTP requests changing the request method to GET after HTTP 303 &quot;See Other&quot; redirect responses.\n   ```\n   \n  \n  \n   ### 2.0.6\n   ```\n   ==================\n\n* Added the ``Cookie`` header to the list of headers to strip from requests when redirecting to a different host. As before, different headers can be set via ``Retry.remove_headers_on_redirect``.\n   ```\n   \n  \n  \n   ### 2.0.5\n   ```\n   ==================\n\n- Allowed pyOpenSSL third-party module without any deprecation warning. (`3126 &lt;https://github.com/urllib3/urllib3/issues/3126&gt;`__)\n- Fixed default ``blocksize`` of ``HTTPConnection`` classes to match high-level classes. Previously was 8KiB, now 16KiB. (`3066 &lt;https://github.com/urllib3/urllib3/issues/3066&gt;`__)\n   ```\n   \n  \n  \n   ### 2.0.4\n   ```\n   ==================\n\n- Added support for union operators to ``HTTPHeaderDict`` (`2254 &lt;https://github.com/urllib3/urllib3/issues/2254&gt;`__)\n- Added ``BaseHTTPResponse`` to ``urllib3.__all__`` (`3078 &lt;https://github.com/urllib3/urllib3/issues/3078&gt;`__)\n- Fixed ``urllib3.connection.HTTPConnection`` to raise the ``http.client.connect`` audit event to have the same behavior as the standard library HTTP client (`2757 &lt;https://github.com/urllib3/urllib3/issues/2757&gt;`__)\n- Relied on the standard library for checking hostnames in supported PyPy releases (`3087 &lt;https://github.com/urllib3/urllib3/issues/3087&gt;`__)\n   ```\n   \n  \n  \n   ### 2.0.3\n   ```\n   ==================\n\n- Allowed alternative SSL libraries such as LibreSSL, while still issuing a warning as we cannot help users facing issues with implementations other than OpenSSL. (`3020 &lt;https://github.com/urllib3/urllib3/issues/3020&gt;`__)\n- Deprecated URLs which don&#x27;t have an explicit scheme (`2950 &lt;https://github.com/urllib3/urllib3/pull/2950&gt;`_)\n- Fixed response decoding with Zstandard when compressed data is made of several frames. (`3008 &lt;https://github.com/urllib3/urllib3/issues/3008&gt;`__)\n- Fixed ``assert_hostname=False`` to correctly skip hostname check. (`3051 &lt;https://github.com/urllib3/urllib3/issues/3051&gt;`__)\n   ```\n   \n  \n  \n   ### 2.0.2\n   ```\n   ==================\n\n- Fixed ``HTTPResponse.stream()`` to continue yielding bytes if buffered decompressed data\n  was still available to be read even if the underlying socket is closed. This prevents\n  a compressed response from being truncated. (`3009 &lt;https://github.com/urllib3/urllib3/issues/3009&gt;`__)\n   ```\n   \n  \n  \n   ### 2.0.1\n   ```\n   ==================\n\n- Fixed a socket leak when fingerprint or hostname verifications fail. (`2991 &lt;https://github.com/urllib3/urllib3/issues/2991&gt;`__)\n- Fixed an error when ``HTTPResponse.read(0)`` was the first ``read`` call or when  ...
#     'created_at': '2023-12-06T14:44:08Z',
#     'updated_at': '2023-12-07T14:44:11Z',
#     'closed_at': '2023-12-07T14:44:11Z',
#     'merged_at': None,
#     'merge_commit_sha': 'd2fc77f5355faaabf94ddc067a781d86dec8a6e7',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls/1549/commits',
#     'review_comments_url': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls/1549/comments',
#     'review_comment_url': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/SekouD/lyricsmaster/issues/1549/comments',
#     'statuses_url': 'https://api.github.com/repos/SekouD/lyricsmaster/statuses/d44476bdc421f716bf14092c4e190694ed85d8a2',
#     'head': {'label': 'SekouD:pyup-scheduled-update-2023-12-06',
#      'ref': 'pyup-scheduled-update-2023-12-06',
#      'sha': 'd44476bdc421f716bf14092c4e190694ed85d8a2',
#      'user': {'login': 'SekouD',
#       'id': 8916344,
#       'node_id': 'MDQ6VXNlcjg5MTYzNDQ=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8916344?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SekouD',
#       'html_url': 'https://github.com/SekouD',
#       'followers_url': 'https://api.github.com/users/SekouD/followers',
#       'following_url': 'https://api.github.com/users/SekouD/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SekouD/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SekouD/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SekouD/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SekouD/orgs',
#       'repos_url': 'https://api.github.com/users/SekouD/repos',
#       'events_url': 'https://api.github.com/users/SekouD/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SekouD/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 103130345,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDMxMzAzNDU=',
#       'name': 'lyricsmaster',
#       'full_name': 'SekouD/lyricsmaster',
#       'private': False,
#       'owner': {'login': 'SekouD',
#        'id': 8916344,
#        'node_id': 'MDQ6VXNlcjg5MTYzNDQ=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/8916344?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/SekouD',
#        'html_url': 'https://github.com/SekouD',
#        'followers_url': 'https://api.github.com/users/SekouD/followers',
#        'following_url': 'https://api.github.com/users/SekouD/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/SekouD/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/SekouD/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/SekouD/subscriptions',
#        'organizations_url': 'https://api.github.com/users/SekouD/orgs',
#        'repos_url': 'https://api.github.com/users/SekouD/repos',
#        'events_url': 'https://api.github.com/users/SekouD/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/SekouD/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/SekouD/lyricsmaster',
#       'description': 'LyricsMaster is a library for downloading lyrics from multiple lyrics providers.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/SekouD/lyricsmaster',
#       'forks_url': 'https://api.github.com/repos/SekouD/lyricsmaster/forks',
#       'keys_url': 'https://api.github.com/repos/SekouD/lyricsmaster/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/SekouD/lyricsmaster/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/SekouD/lyricsmaster/teams',
#       'hooks_url': 'https://api.github.com/repos/SekouD/lyricsmaster/hooks',
#       'issue_events_url': 'https://api.github.com/repos/SekouD/lyricsmaster/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/SekouD/lyricsmaster/events',
#       'assignees_url': 'https://api.github.com/repos/SekouD/lyricsmaster/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/SekouD/lyricsmaster/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/SekouD/lyricsmaster/tags',
#       'blobs_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/SekouD/lyricsmaster/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/SekouD/lyricsmaster/languages',
#       'stargazers_url': 'https://api.github.com/repos/SekouD/lyricsmaster/stargazers',
#       'contributors_url': 'https://api.github.com/repos/SekouD/lyricsmaster/contributors',
#       'subscribers_url': 'https://api.github.com/repos/SekouD/lyricsmaster/subscribers',
#       'subscription_url': 'https://api.github.com/repos/SekouD/lyricsmaster/subscription',
#       'commits_url': 'https://api.github.com/repos/SekouD/lyricsmaster/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/SekouD/lyricsmaster/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/SekouD/lyricsmaster/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/SekouD/lyricsmaster/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/SekouD/lyricsmaster/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/SekouD/lyricsmaster/merges',
#       'archive_url': 'https://api.github.com/repos/SekouD/lyricsmaster/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/SekouD/lyricsmaster/downloads',
#       'issues_url': 'https://api.github.com/repos/SekouD/lyricsmaster/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/SekouD/lyricsmaster/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/SekouD/lyricsmaster/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/SekouD/lyricsmaster/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/SekouD/lyricsmaster/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/SekouD/lyricsmaster/deployments',
#       'created_at': '2017-09-11T11:59:05Z',
#       'updated_at': '2023-03-11T00:01:41Z',
#       'pushed_at': '2023-12-07T14:44:09Z',
#       'git_url': 'git://github.com/SekouD/lyricsmaster.git',
#       'ssh_url': 'git@github.com:SekouD/lyricsmaster.git',
#       'clone_url': 'https://github.com/SekouD/lyricsmaster.git',
#       'svn_url': 'https://github.com/SekouD/lyricsmaster',
#       'homepage': 'https://pypi.python.org/pypi/lyricsmaster',
#       'size': 541,
#       'stargazers_count': 21,
#       'watchers_count': 21,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 8,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 26,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['lyrics', 'python', 'tor'],
#       'visibility': 'public',
#       'forks': 8,
#       'open_issues': 26,
#       'watchers': 21,
#       'default_branch': 'master'}},
#     'base': {'label': 'SekouD:dev',
#      'ref': 'dev',
#      'sha': 'f6f7ba81f540b86f4b1087fee06f24f8170bd1dc',
#      'user': {'login': 'SekouD',
#       'id': 8916344,
#       'node_id': 'MDQ6VXNlcjg5MTYzNDQ=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8916344?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SekouD',
#       'html_url': 'https://github.com/SekouD',
#       'followers_url': 'https://api.github.com/users/SekouD/followers',
#       'following_url': 'https://api.github.com/users/SekouD/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SekouD/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SekouD/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SekouD/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SekouD/orgs',
#       'repos_url': 'https://api.github.com/users/SekouD/repos',
#       'events_url': 'https://api.github.com/users/SekouD/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SekouD/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 103130345,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDMxMzAzNDU=',
#       'name': 'lyricsmaster',
#       'full_name': 'SekouD/lyricsmaster',
#       'private': False,
#       'owner': {'login': 'SekouD',
#        'id': 8916344,
#        'node_id': 'MDQ6VXNlcjg5MTYzNDQ=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/8916344?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/SekouD',
#        'html_url': 'https://github.com/SekouD',
#        'followers_url': 'https://api.github.com/users/SekouD/followers',
#        'following_url': 'https://api.github.com/users/SekouD/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/SekouD/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/SekouD/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/SekouD/subscriptions',
#        'organizations_url': 'https://api.github.com/users/SekouD/orgs',
#        'repos_url': 'https://api.github.com/users/SekouD/repos',
#        'events_url': 'https://api.github.com/users/SekouD/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/SekouD/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/SekouD/lyricsmaster',
#       'description': 'LyricsMaster is a library for downloading lyrics from multiple lyrics providers.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/SekouD/lyricsmaster',
#       'forks_url': 'https://api.github.com/repos/SekouD/lyricsmaster/forks',
#       'keys_url': 'https://api.github.com/repos/SekouD/lyricsmaster/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/SekouD/lyricsmaster/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/SekouD/lyricsmaster/teams',
#       'hooks_url': 'https://api.github.com/repos/SekouD/lyricsmaster/hooks',
#       'issue_events_url': 'https://api.github.com/repos/SekouD/lyricsmaster/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/SekouD/lyricsmaster/events',
#       'assignees_url': 'https://api.github.com/repos/SekouD/lyricsmaster/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/SekouD/lyricsmaster/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/SekouD/lyricsmaster/tags',
#       'blobs_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/SekouD/lyricsmaster/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/SekouD/lyricsmaster/languages',
#       'stargazers_url': 'https://api.github.com/repos/SekouD/lyricsmaster/stargazers',
#       'contributors_url': 'https://api.github.com/repos/SekouD/lyricsmaster/contributors',
#       'subscribers_url': 'https://api.github.com/repos/SekouD/lyricsmaster/subscribers',
#       'subscription_url': 'https://api.github.com/repos/SekouD/lyricsmaster/subscription',
#       'commits_url': 'https://api.github.com/repos/SekouD/lyricsmaster/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/SekouD/lyricsmaster/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/SekouD/lyricsmaster/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/SekouD/lyricsmaster/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/SekouD/lyricsmaster/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/SekouD/lyricsmaster/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/SekouD/lyricsmaster/merges',
#       'archive_url': 'https://api.github.com/repos/SekouD/lyricsmaster/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/SekouD/lyricsmaster/downloads',
#       'issues_url': 'https://api.github.com/repos/SekouD/lyricsmaster/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/SekouD/lyricsmaster/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/SekouD/lyricsmaster/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/SekouD/lyricsmaster/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/SekouD/lyricsmaster/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/SekouD/lyricsmaster/deployments',
#       'created_at': '2017-09-11T11:59:05Z',
#       'updated_at': '2023-03-11T00:01:41Z',
#       'pushed_at': '2023-12-07T14:44:09Z',
#       'git_url': 'git://github.com/SekouD/lyricsmaster.git',
#       'ssh_url': 'git@github.com:SekouD/lyricsmaster.git',
#       'clone_url': 'https://github.com/SekouD/lyricsmaster.git',
#       'svn_url': 'https://github.com/SekouD/lyricsmaster',
#       'homepage': 'https://pypi.python.org/pypi/lyricsmaster',
#       'size': 541,
#       'stargazers_count': 21,
#       'watchers_count': 21,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 8,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 26,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['lyrics', 'python', 'tor'],
#       'visibility': 'public',
#       'forks': 8,
#       'open_issues': 26,
#       'watchers': 21,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls/1549'},
#      'html': {'href': 'https://github.com/SekouD/lyricsmaster/pull/1549'},
#      'issue': {'href': 'https://api.github.com/repos/SekouD/lyricsmaster/issues/1549'},
#      'comments': {'href': 'https://api.github.com/repos/SekouD/lyricsmaster/issues/1549/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls/1549/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/SekouD/lyricsmaster/pulls/1549/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/SekouD/lyricsmaster/statuses/d44476bdc421f716bf14092c4e190694ed85d8a2'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 11,
#     'additions': 11,
#     'deletions': 11,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469214',
#   'type': 'WatchEvent',
#   'actor': {'id': 151705046,
#    'login': 'c-Chmnigma',
#    'display_login': 'c-Chmnigma',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/c-Chmnigma',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/151705046?'},
#   'repo': {'id': 689849471,
#    'name': 'microsoft/TaskWeaver',
#    'url': 'https://api.github.com/repos/microsoft/TaskWeaver'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z',
#   'org': {'id': 6154722,
#    'login': 'microsoft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/microsoft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?'}},
#  {'id': '33981469268',
#   'type': 'CreateEvent',
#   'actor': {'id': 121160453,
#    'login': 'githubkaran2194',
#    'display_login': 'githubkaran2194',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/githubkaran2194',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/121160453?'},
#   'repo': {'id': 728719057,
#    'name': 'githubkaran2194/Practice_ReactJs-master',
#    'url': 'https://api.github.com/repos/githubkaran2194/Practice_ReactJs-master'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469302',
#   'type': 'MemberEvent',
#   'actor': {'id': 21088555,
#    'login': 'iamresp',
#    'display_login': 'iamresp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iamresp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21088555?'},
#   'repo': {'id': 719138473,
#    'name': 'iamresp/axcodewars',
#    'url': 'https://api.github.com/repos/iamresp/axcodewars'},
#   'payload': {'member': {'login': 'TemVin',
#     'id': 27205145,
#     'node_id': 'MDQ6VXNlcjI3MjA1MTQ1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/27205145?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/TemVin',
#     'html_url': 'https://github.com/TemVin',
#     'followers_url': 'https://api.github.com/users/TemVin/followers',
#     'following_url': 'https://api.github.com/users/TemVin/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/TemVin/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/TemVin/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/TemVin/subscriptions',
#     'organizations_url': 'https://api.github.com/users/TemVin/orgs',
#     'repos_url': 'https://api.github.com/users/TemVin/repos',
#     'events_url': 'https://api.github.com/users/TemVin/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/TemVin/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469266',
#   'type': 'PushEvent',
#   'actor': {'id': 1136927,
#    'login': 'danidiaz',
#    'display_login': 'danidiaz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danidiaz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1136927?'},
#   'repo': {'id': 398014216,
#    'name': 'danidiaz/variegated-reading-lists',
#    'url': 'https://api.github.com/repos/danidiaz/variegated-reading-lists'},
#   'payload': {'repository_id': 398014216,
#    'push_id': 16175254783,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b21e2b0f21ed0c10e920c1e4805e7e4f6f890705',
#    'before': '864ecfe85241f5e130b815fbec11e948cd2ff070',
#    'commits': [{'sha': 'b21e2b0f21ed0c10e920c1e4805e7e4f6f890705',
#      'author': {'email': 'diaz.carrete@gmail.com',
#       'name': 'Daniel Díaz Carrete'},
#      'message': 'quants',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/danidiaz/variegated-reading-lists/commits/b21e2b0f21ed0c10e920c1e4805e7e4f6f890705'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469216',
#   'type': 'PushEvent',
#   'actor': {'id': 84422593,
#    'login': 'MrMilhas',
#    'display_login': 'MrMilhas',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MrMilhas',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84422593?'},
#   'repo': {'id': 698967214,
#    'name': 'MrMilhas/IC_Trabalho_1',
#    'url': 'https://api.github.com/repos/MrMilhas/IC_Trabalho_1'},
#   'payload': {'repository_id': 698967214,
#    'push_id': 16175254749,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cfa6e820baeaca3bcc65b5238c652e04df56930b',
#    'before': 'd501957db5112cc8c1d6aefae98cf3c74344456e',
#    'commits': [{'sha': 'cfa6e820baeaca3bcc65b5238c652e04df56930b',
#      'author': {'email': 'danielmrezende@yahoo.com.br', 'name': 'MrMilhas'},
#      'message': 'Implementando calculo da velocidade e atualização da posição',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MrMilhas/IC_Trabalho_1/commits/cfa6e820baeaca3bcc65b5238c652e04df56930b'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469235',
#   'type': 'PushEvent',
#   'actor': {'id': 43733305,
#    'login': 'yanonono',
#    'display_login': 'yanonono',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yanonono',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43733305?'},
#   'repo': {'id': 183440182,
#    'name': 'yanonono/booth-update',
#    'url': 'https://api.github.com/repos/yanonono/booth-update'},
#   'payload': {'repository_id': 183440182,
#    'push_id': 16175254782,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1ddd15ea702b4cf91b19f66242ba35b23c694b1a',
#    'before': 'b10661648ca0dec5f4d45bfad89d9503a91c77ed',
#    'commits': [{'sha': '1ddd15ea702b4cf91b19f66242ba35b23c694b1a',
#      'author': {'email': 'yano.nono.0701+booth-github@gmail.com',
#       'name': 'yano.nono'},
#      'message': 'updated at: 2023-12-07 23:44, 3Dモデル\u30005.56mm PDW/アサルトカービン - Vacssのモデル置き場 - BOOTH',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yanonono/booth-update/commits/1ddd15ea702b4cf91b19f66242ba35b23c694b1a'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469257',
#   'type': 'MemberEvent',
#   'actor': {'id': 32870596,
#    'login': 'aimagelab',
#    'display_login': 'aimagelab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aimagelab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32870596?'},
#   'repo': {'id': 728719093,
#    'name': 'aimagelab/regesta_OCR',
#    'url': 'https://api.github.com/repos/aimagelab/regesta_OCR'},
#   'payload': {'member': {'login': 'quattrinifabio',
#     'id': 38918787,
#     'node_id': 'MDQ6VXNlcjM4OTE4Nzg3',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/38918787?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/quattrinifabio',
#     'html_url': 'https://github.com/quattrinifabio',
#     'followers_url': 'https://api.github.com/users/quattrinifabio/followers',
#     'following_url': 'https://api.github.com/users/quattrinifabio/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/quattrinifabio/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/quattrinifabio/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/quattrinifabio/subscriptions',
#     'organizations_url': 'https://api.github.com/users/quattrinifabio/orgs',
#     'repos_url': 'https://api.github.com/users/quattrinifabio/repos',
#     'events_url': 'https://api.github.com/users/quattrinifabio/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/quattrinifabio/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z',
#   'org': {'id': 32870596,
#    'login': 'aimagelab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aimagelab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32870596?'}},
#  {'id': '33981469241',
#   'type': 'CreateEvent',
#   'actor': {'id': 143796541,
#    'login': 'Rakesh-kumar-2001',
#    'display_login': 'Rakesh-kumar-2001',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rakesh-kumar-2001',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/143796541?'},
#   'repo': {'id': 728719069,
#    'name': 'Rakesh-kumar-2001/ToDo',
#    'url': 'https://api.github.com/repos/Rakesh-kumar-2001/ToDo'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469198',
#   'type': 'PushEvent',
#   'actor': {'id': 8493765,
#    'login': 'qsantos',
#    'display_login': 'qsantos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/qsantos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8493765?'},
#   'repo': {'id': 653205139,
#    'name': 'helsing-ai/buffrs',
#    'url': 'https://api.github.com/repos/helsing-ai/buffrs'},
#   'payload': {'repository_id': 653205139,
#    'push_id': 16175254723,
#    'size': 17,
#    'distinct_size': 5,
#    'ref': 'refs/heads/pre-commit',
#    'head': 'c719bd940f5ccad3c791b0b1d181ba6e10b5fe17',
#    'before': 'd7fb9555003ecca2301123d05312d72463bd90ec',
#    'commits': [{'sha': '24202b879f226284b2002157ee504e05257d46f8',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Unignore registry test can_publish_and_fetch',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/24202b879f226284b2002157ee504e05257d46f8'},
#     {'sha': 'd33f555acd1b8eb9b5760420c5e9fe269243eef2',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Compare package contents instead of hash in tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/d33f555acd1b8eb9b5760420c5e9fe269243eef2'},
#     {'sha': 'e693bd083b6b80a6646e0ba67b11198742710a7d',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Unignore and update cmd::package::fixture test',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/e693bd083b6b80a6646e0ba67b11198742710a7d'},
#     {'sha': '30fdbcba22e971cb4f23840a4ac426a92f537f27',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Remove unneeded clone',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/30fdbcba22e971cb4f23840a4ac426a92f537f27'},
#     {'sha': '3cb9bae7bd65ba4a12afd796bc9975c1285d8af7',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Update expected package for cmd::package::fixture',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/3cb9bae7bd65ba4a12afd796bc9975c1285d8af7'},
#     {'sha': '841d288b231a7cf5611b1cbc66fe7891e845d01b',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Remove hash comparison from test VirtualFileSystem',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/841d288b231a7cf5611b1cbc66fe7891e845d01b'},
#     {'sha': 'd1f90957ebc27356b126aa79da317b97b1031154',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Move read_package in Package-comparison branch',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/d1f90957ebc27356b126aa79da317b97b1031154'},
#     {'sha': 'f879d2671235900257908f10bbecde2307233504',
#      'author': {'email': 'qsantos@qsantos.fr', 'name': 'Quentin Santos'},
#      'message': 'Merge pull request #189 from helsing-ai/unignore-tests\n\nUnignore tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/f879d2671235900257908f10bbecde2307233504'},
#     {'sha': '501eaab1fa4416d5253902c0d655c22f1bd69059',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Add Cargo.lock to git',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/501eaab1fa4416d5253902c0d655c22f1bd69059'},
#     {'sha': 'b576ebb92c51d635d7c87a295c0147582e0de4cb',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Remove unused dependencies',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/b576ebb92c51d635d7c87a295c0147582e0de4cb'},
#     {'sha': 'dfbc1daa61756cc6e07f74540129a7dd5be47257',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Ignore registry/proto/vendor/',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/dfbc1daa61756cc6e07f74540129a7dd5be47257'},
#     {'sha': '8d47192999292d9f47d64f0dfaf5b3fcdc044f34',
#      'author': {'email': 'qsantos@qsantos.fr', 'name': 'Quentin Santos'},
#      'message': 'Merge pull request #190 from helsing-ai/registry-cargo-lock\n\nAdd a Cargo.lock to the registry crate',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/8d47192999292d9f47d64f0dfaf5b3fcdc044f34'},
#     {'sha': '889c2cc6d8cb11aaa5747205d22d066020bad9dc',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Add pre-commit hook',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/889c2cc6d8cb11aaa5747205d22d066020bad9dc'},
#     {'sha': 'e5476c74330527561f9c4b0398d8493621d1159b',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Run typos in pre-commit hook if installed',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/e5476c74330527561f9c4b0398d8493621d1159b'},
#     {'sha': '0a7f1e74eebb74a5da766cf4c5a3f8ebb102f04b',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Fix shell command interpreted as doctest',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/0a7f1e74eebb74a5da766cf4c5a3f8ebb102f04b'},
#     {'sha': '2db16a96fa7f6a04210461b6f3ebd338970a2e2e',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Split Contributing section from README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/2db16a96fa7f6a04210461b6f3ebd338970a2e2e'},
#     {'sha': 'c719bd940f5ccad3c791b0b1d181ba6e10b5fe17',
#      'author': {'email': 'quentin.santos@helsing.ai',
#       'name': 'Quentin Santos'},
#      'message': 'Move pre-commit to .github/',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/helsing-ai/buffrs/commits/c719bd940f5ccad3c791b0b1d181ba6e10b5fe17'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z',
#   'org': {'id': 119670433,
#    'login': 'helsing-ai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/helsing-ai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119670433?'}},
#  {'id': '33981469180',
#   'type': 'PushEvent',
#   'actor': {'id': 85299065,
#    'login': 'Almadavic',
#    'display_login': 'Almadavic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Almadavic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85299065?'},
#   'repo': {'id': 526211873,
#    'name': 'Almadavic/Almadavic',
#    'url': 'https://api.github.com/repos/Almadavic/Almadavic'},
#   'payload': {'repository_id': 526211873,
#    'push_id': 16175254735,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '49efa90c3126443c7463efc00c08e323fbcdbdac',
#    'before': 'cb77cc00f74f7b2bd1b68672f43bd510de317e07',
#    'commits': [{'sha': '49efa90c3126443c7463efc00c08e323fbcdbdac',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'readme-bot'},
#      'message': 'Updated with Dev Metrics',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Almadavic/Almadavic/commits/49efa90c3126443c7463efc00c08e323fbcdbdac'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469219',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 17914399,
#    'login': 'bkeryan',
#    'display_login': 'bkeryan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bkeryan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17914399?'},
#   'repo': {'id': 444306419,
#    'name': 'ni/measurementlink-python',
#    'url': 'https://api.github.com/repos/ni/measurementlink-python'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/ni/measurementlink-python/pulls/comments/1419073888',
#     'pull_request_review_id': 1770321723,
#     'id': 1419073888,
#     'node_id': 'PRRC_kwDOGnuT885UlVlg',
#     'diff_hunk': '',
#     'path': 'examples/nidcpower_source_dc_voltage/NIDCPowerSourceDCVoltage.seq',
#     'commit_id': '10b2955f17bdc5182dbf79977a94693a4ac5530d',
#     'original_commit_id': '10b2955f17bdc5182dbf79977a94693a4ac5530d',
#     'user': {'login': 'bkeryan',
#      'id': 17914399,
#      'node_id': 'MDQ6VXNlcjE3OTE0Mzk5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/17914399?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bkeryan',
#      'html_url': 'https://github.com/bkeryan',
#      'followers_url': 'https://api.github.com/users/bkeryan/followers',
#      'following_url': 'https://api.github.com/users/bkeryan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bkeryan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bkeryan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bkeryan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bkeryan/orgs',
#      'repos_url': 'https://api.github.com/users/bkeryan/repos',
#      'events_url': 'https://api.github.com/users/bkeryan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bkeryan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'I diffed this locally using the TestStand Diff/Merge Utility and it looks fine.',
#     'created_at': '2023-12-07T14:43:07Z',
#     'updated_at': '2023-12-07T14:44:11Z',
#     'html_url': 'https://github.com/ni/measurementlink-python/pull/538#discussion_r1419073888',
#     'pull_request_url': 'https://api.github.com/repos/ni/measurementlink-python/pulls/538',
#     'author_association': 'COLLABORATOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/ni/measurementlink-python/pulls/comments/1419073888'},
#      'html': {'href': 'https://github.com/ni/measurementlink-python/pull/538#discussion_r1419073888'},
#      'pull_request': {'href': 'https://api.github.com/repos/ni/measurementlink-python/pulls/538'}},
#     'reactions': {'url': 'https://api.github.com/repos/ni/measurementlink-python/pulls/comments/1419073888/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': 1,
#     'original_line': 1,
#     'side': 'RIGHT',
#     'original_position': 1,
#     'position': 1,
#     'subject_type': 'file'},
#    'pull_request': {'url': 'https://api.github.com/repos/ni/measurementlink-python/pulls/538',
#     'id': 1632718259,
#     'node_id': 'PR_kwDOGnuT885hUU2z',
#     'html_url': 'https://github.com/ni/measurementlink-python/pull/538',
#     'diff_url': 'https://github.com/ni/measurementlink-python/pull/538.diff',
#     'patch_url': 'https://github.com/ni/measurementlink-python/pull/538.patch',
#     'issue_url': 'https://api.github.com/repos/ni/measurementlink-python/issues/538',
#     'number': 538,
#     'state': 'open',
#     'locked': False,
#     'title': 'examples: Update NI-DCPower TestStand sequence with the Update pin map custom step',
#     'user': {'login': 'Avinash2Suresh',
#      'id': 147520106,
#      'node_id': 'U_kgDOCMr6ag',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/147520106?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Avinash2Suresh',
#      'html_url': 'https://github.com/Avinash2Suresh',
#      'followers_url': 'https://api.github.com/users/Avinash2Suresh/followers',
#      'following_url': 'https://api.github.com/users/Avinash2Suresh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Avinash2Suresh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Avinash2Suresh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Avinash2Suresh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Avinash2Suresh/orgs',
#      'repos_url': 'https://api.github.com/users/Avinash2Suresh/repos',
#      'events_url': 'https://api.github.com/users/Avinash2Suresh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Avinash2Suresh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '- [x] This contribution adheres to [CONTRIBUTING.md](https://github.com/ni/measurement-services-python/blob/main/CONTRIBUTING.md).\r\n\r\n### What does this Pull Request accomplish?\r\n- The Update Pin map and Clean up action steps are replaced with the "Update pin map" step.\r\n- Removed the `teststand_pinmap.py` file and an unused function in `_helpers.py` in the `../examples/nidcpower_source_dc_voltage/` directory.\r\n- Removed the `FileGlobals.MeasurementLink.PinMapPath` from the sequence.\r\n\r\n### Why should this Pull Request be merged?\r\nUpdates the `NIDCPowerSourceDCVoltage.seq` to use the "Update pin map" step - [Task 2586977](https://dev.azure.com/ni/DevCentral/_workitems/edit/2586977).\r\n\r\n### What testing has been done?\r\nRan the NI-DCPower sequence with the simulated NI-DCPower instrument by using the TestStand measurement client that is available in the main branch.',
#     'created_at': '2023-12-06T15:20:18Z',
#     'updated_at': '2023-12-07T14:44:11Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'b4ebfae59fc447eb2054f38ba38cad5d673dd20d',
#     'assignee': {'login': 'Avinash2Suresh',
#      'id': 147520106,
#      'node_id': 'U_kgDOCMr6ag',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/147520106?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Avinash2Suresh',
#      'html_url': 'https://github.com/Avinash2Suresh',
#      'followers_url': 'https://api.github.com/users/Avinash2Suresh/followers',
#      'following_url': 'https://api.github.com/users/Avinash2Suresh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Avinash2Suresh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Avinash2Suresh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Avinash2Suresh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Avinash2Suresh/orgs',
#      'repos_url': 'https://api.github.com/users/Avinash2Suresh/repos',
#      'events_url': 'https://api.github.com/users/Avinash2Suresh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Avinash2Suresh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'Avinash2Suresh',
#       'id': 147520106,
#       'node_id': 'U_kgDOCMr6ag',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/147520106?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Avinash2Suresh',
#       'html_url': 'https://github.com/Avinash2Suresh',
#       'followers_url': 'https://api.github.com/users/Avinash2Suresh/followers',
#       'following_url': 'https://api.github.com/users/Avinash2Suresh/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Avinash2Suresh/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Avinash2Suresh/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Avinash2Suresh/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Avinash2Suresh/orgs',
#       'repos_url': 'https://api.github.com/users/Avinash2Suresh/repos',
#       'events_url': 'https://api.github.com/users/Avinash2Suresh/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Avinash2Suresh/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [{'login': 'csjall',
#       'id': 4081815,
#       'node_id': 'MDQ6VXNlcjQwODE4MTU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/4081815?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/csjall',
#       'html_url': 'https://github.com/csjall',
#       'followers_url': 'https://api.github.com/users/csjall/followers',
#       'following_url': 'https://api.github.com/users/csjall/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/csjall/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/csjall/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/csjall/subscriptions',
#       'organizations_url': 'https://api.github.com/users/csjall/orgs',
#       'repos_url': 'https://api.github.com/users/csjall/repos',
# ...
#       'private': False,
#       'owner': {'login': 'getsentry',
#        'id': 1396951,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzOTY5NTE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1396951?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/getsentry',
#        'html_url': 'https://github.com/getsentry',
#        'followers_url': 'https://api.github.com/users/getsentry/followers',
#        'following_url': 'https://api.github.com/users/getsentry/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/getsentry/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/getsentry/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/getsentry/subscriptions',
#        'organizations_url': 'https://api.github.com/users/getsentry/orgs',
#        'repos_url': 'https://api.github.com/users/getsentry/repos',
#        'events_url': 'https://api.github.com/users/getsentry/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/getsentry/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/getsentry/profiling-node',
#       'description': 'Profiling for Node',
#       'fork': False,
#       'url': 'https://api.github.com/repos/getsentry/profiling-node',
#       'forks_url': 'https://api.github.com/repos/getsentry/profiling-node/forks',
#       'keys_url': 'https://api.github.com/repos/getsentry/profiling-node/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/getsentry/profiling-node/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/getsentry/profiling-node/teams',
#       'hooks_url': 'https://api.github.com/repos/getsentry/profiling-node/hooks',
#       'issue_events_url': 'https://api.github.com/repos/getsentry/profiling-node/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/getsentry/profiling-node/events',
#       'assignees_url': 'https://api.github.com/repos/getsentry/profiling-node/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/getsentry/profiling-node/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/getsentry/profiling-node/tags',
#       'blobs_url': 'https://api.github.com/repos/getsentry/profiling-node/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/getsentry/profiling-node/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/getsentry/profiling-node/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/getsentry/profiling-node/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/getsentry/profiling-node/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/getsentry/profiling-node/languages',
#       'stargazers_url': 'https://api.github.com/repos/getsentry/profiling-node/stargazers',
#       'contributors_url': 'https://api.github.com/repos/getsentry/profiling-node/contributors',
#       'subscribers_url': 'https://api.github.com/repos/getsentry/profiling-node/subscribers',
#       'subscription_url': 'https://api.github.com/repos/getsentry/profiling-node/subscription',
#       'commits_url': 'https://api.github.com/repos/getsentry/profiling-node/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/getsentry/profiling-node/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/getsentry/profiling-node/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/getsentry/profiling-node/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/getsentry/profiling-node/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/getsentry/profiling-node/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/getsentry/profiling-node/merges',
#       'archive_url': 'https://api.github.com/repos/getsentry/profiling-node/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/getsentry/profiling-node/downloads',
#       'issues_url': 'https://api.github.com/repos/getsentry/profiling-node/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/getsentry/profiling-node/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/getsentry/profiling-node/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/getsentry/profiling-node/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/getsentry/profiling-node/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/getsentry/profiling-node/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/getsentry/profiling-node/deployments',
#       'created_at': '2022-07-05T18:57:47Z',
#       'updated_at': '2023-11-14T21:03:45Z',
#       'pushed_at': '2023-12-07T14:44:11Z',
#       'git_url': 'git://github.com/getsentry/profiling-node.git',
#       'ssh_url': 'git@github.com:getsentry/profiling-node.git',
#       'clone_url': 'https://github.com/getsentry/profiling-node.git',
#       'svn_url': 'https://github.com/getsentry/profiling-node',
#       'homepage': '',
#       'size': 2684,
#       'stargazers_count': 23,
#       'watchers_count': 23,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 8,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 11,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['tag-production'],
#       'visibility': 'public',
#       'forks': 8,
#       'open_issues': 11,
#       'watchers': 23,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/getsentry/profiling-node/pulls/220'},
#      'html': {'href': 'https://github.com/getsentry/profiling-node/pull/220'},
#      'issue': {'href': 'https://api.github.com/repos/getsentry/profiling-node/issues/220'},
#      'comments': {'href': 'https://api.github.com/repos/getsentry/profiling-node/issues/220/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/getsentry/profiling-node/pulls/220/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/getsentry/profiling-node/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/getsentry/profiling-node/pulls/220/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/getsentry/profiling-node/statuses/abe3bdd9c7726cfd64fc8f169094604fdff40ad8'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 85,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z',
#   'org': {'id': 1396951,
#    'login': 'getsentry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/getsentry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1396951?'}},
#  {'id': '33981469013',
#   'type': 'PushEvent',
#   'actor': {'id': 145701180,
#    'login': 'lvlivingston',
#    'display_login': 'lvlivingston',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lvlivingston',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/145701180?'},
#   'repo': {'id': 728455622,
#    'name': 'lvlivingston/cat-collector',
#    'url': 'https://api.github.com/repos/lvlivingston/cat-collector'},
#   'payload': {'repository_id': 728455622,
#    'push_id': 16175254669,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4b64fae1ed49e405293e9025044190fb4b99dcff',
#    'before': 'c71997e0761af80d0f19e087cd01655d66810e1d',
#    'commits': [{'sha': '4b64fae1ed49e405293e9025044190fb4b99dcff',
#      'author': {'email': 'lvlivingston@gmail.com', 'name': 'lvlivingston'},
#      'message': 'created about page',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lvlivingston/cat-collector/commits/4b64fae1ed49e405293e9025044190fb4b99dcff'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469143',
#   'type': 'PushEvent',
#   'actor': {'id': 122015690,
#    'login': 'Guiggzz',
#    'display_login': 'Guiggzz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Guiggzz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/122015690?'},
#   'repo': {'id': 725681231,
#    'name': 'Guiggzz/RPGpython',
#    'url': 'https://api.github.com/repos/Guiggzz/RPGpython'},
#   'payload': {'repository_id': 725681231,
#    'push_id': 16175254715,
#    'size': 5,
#    'distinct_size': 5,
#    'ref': 'refs/heads/main',
#    'head': '868ed0565051fcf6ca9efdff48a645821f88a77c',
#    'before': 'd72e69e56da9b8a2825fd512b73f47a86e2fbce0',
#    'commits': [{'sha': '77c03628895313128658b333b918eb2ca6020a37',
#      'author': {'email': 'guillaume.breon@gmail.com', 'name': 'guigz'},
#      'message': 'Revert "ardzdzf"\n\nThis reverts commit d72e69e56da9b8a2825fd512b73f47a86e2fbce0.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Guiggzz/RPGpython/commits/77c03628895313128658b333b918eb2ca6020a37'},
#     {'sha': '7b831625f052fd9e793e45d3743ed3bb3f8d905d',
#      'author': {'email': 'guillaume.breon@gmail.com', 'name': 'guigz'},
#      'message': 'Revert "tout les nlv modif"\n\nThis reverts commit 79d44aa4eeee1cdac77e17484eba6c6b9cb8ac80.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Guiggzz/RPGpython/commits/7b831625f052fd9e793e45d3743ed3bb3f8d905d'},
#     {'sha': '2edede07214fd3f23366d88072da5fbeb6e67db0',
#      'author': {'email': 'guillaume.breon@gmail.com', 'name': 'guigz'},
#      'message': 'Revert "dzededepioeàjfzçodfpze"\n\nThis reverts commit 4465f4b4f81e0f7ef23e197a44399778da7f3755.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Guiggzz/RPGpython/commits/2edede07214fd3f23366d88072da5fbeb6e67db0'},
#     {'sha': '7bf22809d6cbeba3f369317030d411d51b4612fd',
#      'author': {'email': 'guillaume.breon@gmail.com', 'name': 'guigz'},
#      'message': 'Revert "dzedede"\n\nThis reverts commit 847650b2660091df382cb9cc32ac09eabe15637f, reversing\nchanges made to 4878975bff57c8df264048e43f1cbcd53f951742.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Guiggzz/RPGpython/commits/7bf22809d6cbeba3f369317030d411d51b4612fd'},
#     {'sha': '868ed0565051fcf6ca9efdff48a645821f88a77c',
#      'author': {'email': 'guillaume.breon@gmail.com', 'name': 'guigz'},
#      'message': 'Revert "tout"\n\nThis reverts commit 4878975bff57c8df264048e43f1cbcd53f951742.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Guiggzz/RPGpython/commits/868ed0565051fcf6ca9efdff48a645821f88a77c'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469160',
#   'type': 'PushEvent',
#   'actor': {'id': 82547306,
#    'login': 'akonarsnyker',
#    'display_login': 'akonarsnyker',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/akonarsnyker',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82547306?'},
#   'repo': {'id': 358057490,
#    'name': 'akonarsnyker/goof',
#    'url': 'https://api.github.com/repos/akonarsnyker/goof'},
#   'payload': {'repository_id': 358057490,
#    'push_id': 16175254734,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/snyk-fix-cbd67f684f1d1b07db8fc6436765d0b4',
#    'head': 'f229aa02307e7d87b40f6c7afc74e0b68d058b92',
#    'before': 'd630d18ed7a4a867611cb65a07afd6b4932fc228',
#    'commits': [{'sha': 'f229aa02307e7d87b40f6c7afc74e0b68d058b92',
#      'author': {'email': 'snyk-bot@snyk.io', 'name': 'snyk-bot'},
#      'message': 'fix: package.json & package-lock.json to reduce vulnerabilities\n\nThe following vulnerabilities are fixed with an upgrade:\n- https://snyk.io/vuln/SNYK-JS-BABELTRAVERSE-5962463\n- https://snyk.io/vuln/SNYK-JS-INFLIGHT-6095116',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/akonarsnyker/goof/commits/f229aa02307e7d87b40f6c7afc74e0b68d058b92'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981468998',
#   'type': 'PushEvent',
#   'actor': {'id': 153171526,
#    'login': 'c1darja0vY',
#    'display_login': 'c1darja0vY',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/c1darja0vY',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153171526?'},
#   'repo': {'id': 728562070,
#    'name': 'c1darja0vY/ubiquitous-octo-doodle',
#    'url': 'https://api.github.com/repos/c1darja0vY/ubiquitous-octo-doodle'},
#   'payload': {'repository_id': 728562070,
#    'push_id': 16175254650,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2b768f6e06a6c521f881a2284f638b2fb77354d0',
#    'before': '5296bcddc0b88d403feedf4dd6becbd11c593f93',
#    'commits': [{'sha': '2b768f6e06a6c521f881a2284f638b2fb77354d0',
#      'author': {'email': '153171526+c1darja0vY@users.noreply.github.com',
#       'name': 'c1darja0vY'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/c1darja0vY/ubiquitous-octo-doodle/commits/2b768f6e06a6c521f881a2284f638b2fb77354d0'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469106',
#   'type': 'CreateEvent',
#   'actor': {'id': 153202955,
#    'login': 'DevGeovani',
#    'display_login': 'DevGeovani',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DevGeovani',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153202955?'},
#   'repo': {'id': 728719070,
#    'name': 'DevGeovani/TurismoDigital',
#    'url': 'https://api.github.com/repos/DevGeovani/TurismoDigital'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'},
#  {'id': '33981469032',
#   'type': 'WatchEvent',
#   'actor': {'id': 106041998,
#    'login': 'accpatrick',
#    'display_login': 'accpatrick',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/accpatrick',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106041998?'},
#   'repo': {'id': 658826129,
#    'name': 'princeton-nlp/intercode',
#    'url': 'https://api.github.com/repos/princeton-nlp/intercode'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z',
#   'org': {'id': 44678448,
#    'login': 'princeton-nlp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/princeton-nlp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44678448?'}},
#  {'id': '33981469035',
#   'type': 'PushEvent',
#   'actor': {'id': 153174850,
#    'login': 'h5rodriguez2lT',
#    'display_login': 'h5rodriguez2lT',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/h5rodriguez2lT',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153174850?'},
#   'repo': {'id': 728578176,
#    'name': 'h5rodriguez2lT/shiny-sniffle',
#    'url': 'https://api.github.com/repos/h5rodriguez2lT/shiny-sniffle'},
#   'payload': {'repository_id': 728578176,
#    'push_id': 16175254658,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1bf20028d164900bfc3b44e6bebb728c63c222cf',
#    'before': 'b863b7321f32e052d1c372cc09479f29d09975bb',
#    'commits': [{'sha': '1bf20028d164900bfc3b44e6bebb728c63c222cf',
#      'author': {'email': '153174850+h5rodriguez2lT@users.noreply.github.com',
#       'name': 'h5rodriguez2lT'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/h5rodriguez2lT/shiny-sniffle/commits/1bf20028d164900bfc3b44e6bebb728c63c222cf'}]},
#   'public': True,
#   'created_at': '2023-12-07T14:44:12Z'}]

# %%
# Conteúdo bruto da resposta
## Caso queira obter a resposta bruta do soquete do servidor.

# %%
r = requests.get('https://api.github.com/events', stream=True)

# %%
r.raw

# %%
r.raw.read(10)
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03'

# %%
with open("arquivo", 'wb') as fd:
    for chunk in r.iter_content(chunk_size=128):
        fd.write(chunk)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\response.py:761, in HTTPResponse._update_chunk_length(self)
#     760 try:
# --> 761     self.chunk_left = int(line, 16)
#     762 except ValueError:
#     763     # Invalid chunked protocol response, abort.
#
# ValueError: invalid literal for int() with base 16: b'\xed}[o$Iv\xde_Is0\xd0J3\xc5\xca\xfb\x85\xf0Z\xc3\xbeN\xef\x0e\xbb{\xba\xd9\xda\xd9\x99\x1dP\x9172\x9b\xc5\xca\xda\xca*\xf6\xb0\x891\x04[\x16\xfc`C\x0fk\x18\x16\x0cC~\x90eX\xf0\x83a\xfb\xc1\x80\xed7
#
# During handling of the above exception, another exception occurred:
#
# InvalidChunkLength                        Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\response.py:444, in HTTPResponse._error_catcher(self)
#     443 try:
# --> 444     yield
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\response.py:828, in HTTPResponse.read_chunked(self, amt, decode_content)
#     827 while True:
# --> 828     self._update_chunk_length()
#     829     if self.chunk_left == 0:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\response.py:765, in HTTPResponse._update_chunk_length(self)
#     764 self.close()
# --> 765 raise InvalidChunkLength(self, line)
#
# InvalidChunkLength: InvalidChunkLength(got length b'\xed}[o$Iv\xde_Is0\xd0J3\xc5\xca\xfb\x85\xf0Z\xc3\xbeN\xef\x0e\xbb{\xba\xd9\xda\xd9\x99\x1dP\x9172\x9b\xc5\xca\xda\xca*\xf6\xb0\x891\x04[\x16\xfc`C\x0fk\x18\x16\x0cC~\x90eX\xf0\x83a\xfb\xc1\x80\xed7\xeb\x8f\xf8M\x1a\x19\xd6O\xf0w"\xf2\x9eYUy\xa9^HV\xedb\x9adU\xc6\x89\xc8\x888\'\xe2\xdc\xbe\xf3\xcd\xfdQ\xe4\x1f\x9d\x1ci\x9ac+\xba-', 10 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\response.py:816, in HTTPResponse.read_chunked(self, amt, decode_content)
#     811     raise BodyNotHttplibCompatible(
#     812         "Body should be http.client.HTTPResponse like. "
#     813         "It should have have an fp attribute which returns raw chunks."
#     814     )
# --> 816 with self._error_catcher():
#     817     # Don't bother reading the body of a HEAD request.
#     818     if self._original_response and is_response_to_head(self._original_response):
#
# File ~\AppData\Local\anaconda3\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\response.py:461, in HTTPResponse._error_catcher(self)
#     459 except (HTTPException, SocketError) as e:
#     460     # This includes IncompleteRead.
# --> 461     raise ProtocolError("Connection broken: %r" % e, e)
#     463 # If no exception is thrown, we should avoid cleaning up
#     464 # unnecessarily.
#
# ProtocolError: ('Connection broken: InvalidChunkLength(got length b\'\\xed}[o$Iv\\xde_Is0\\xd0J3\\xc5\\xca\\xfb\\x85\\xf0Z\\xc3\\xbeN\\xef\\x0e\\xbb{\\xba\\xd9\\xda\\xd9\\x99\\x1dP\\x9172\\x9b\\xc5\\xca\\xda\\xca*\\xf6\\xb0\\x891\\x04[\\x16\\xfc`C\\x0fk\\x18\\x16\\x0cC~\\x90eX\\xf0\\x83a\\xfb\\xc1\\x80\\xed7\\xeb\\x8f\\xf8M\\x1a\\x19\\xd6O\\xf0w"\\xf2\\x9eYUy\\xa9^HV\\xedb\\x9adU\\xc6\\x89\\xc8\\x888\\\'\\xe2\\xdc\\xbe\\xf3\\xcd\\xfdQ\\xe4\\x1f\\x9d\\x1ci\\x9ac+\\xba-\', 10 bytes read)', InvalidChunkLength(got length b'\xed}[o$Iv\xde_Is0\xd0J3\xc5\xca\xfb\x85\xf0Z\xc3\xbeN\xef\x0e\xbb{\xba\xd9\xda\xd9\x99\x1dP\x9172\x9b\xc5\xca\xda\xca*\xf6\xb0\x891\x04[\x16\xfc`C\x0fk\x18\x16\x0cC~\x90eX\xf0\x83a\xfb\xc1\x80\xed7\xeb\x8f\xf8M\x1a\x19\xd6O\xf0w"\xf2\x9eYUy\xa9^HV\xedb\x9adU\xc6\x89\xc8\x888\'\xe2\xdc\xbe\xf3\xcd\xfdQ\xe4\x1f\x9d\x1ci\x9ac+\xba-', 10 bytes read))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[30], line 2
#       1 with open("arquivo", 'wb') as fd:
# ----> 2     for chunk in r.iter_content(chunk_size=128):
#       3         fd.write(chunk)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\requests\models.py:818, in Response.iter_content.<locals>.generate()
#     816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
# --> 818     raise ChunkedEncodingError(e)
#     819 except DecodeError as e:
#     820     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ('Connection broken: InvalidChunkLength(got length b\'\\xed}[o$Iv\\xde_Is0\\xd0J3\\xc5\\xca\\xfb\\x85\\xf0Z\\xc3\\xbeN\\xef\\x0e\\xbb{\\xba\\xd9\\xda\\xd9\\x99\\x1dP\\x9172\\x9b\\xc5\\xca\\xda\\xca*\\xf6\\xb0\\x891\\x04[\\x16\\xfc`C\\x0fk\\x18\\x16\\x0cC~\\x90eX\\xf0\\x83a\\xfb\\xc1\\x80\\xed7\\xeb\\x8f\\xf8M\\x1a\\x19\\xd6O\\xf0w"\\xf2\\x9eYUy\\xa9^HV\\xedb\\x9adU\\xc6\\x89\\xc8\\x888\\\'\\xe2\\xdc\\xbe\\xf3\\xcd\\xfdQ\\xe4\\x1f\\x9d\\x1ci\\x9ac+\\xba-\', 10 bytes read)', InvalidChunkLength(got length b'\xed}[o$Iv\xde_Is0\xd0J3\xc5\xca\xfb\x85\xf0Z\xc3\xbeN\xef\x0e\xbb{\xba\xd9\xda\xd9\x99\x1dP\x9172\x9b\xc5\xca\xda\xca*\xf6\xb0\x891\x04[\x16\xfc`C\x0fk\x18\x16\x0cC~\x90eX\xf0\x83a\xfb\xc1\x80\xed7\xeb\x8f\xf8M\x1a\x19\xd6O\xf0w"\xf2\x9eYUy\xa9^HV\xedb\x9adU\xc6\x89\xc8\x888\'\xe2\xdc\xbe\xf3\xcd\xfdQ\xe4\x1f\x9d\x1ci\x9ac+\xba-', 10 bytes read))

# %% [markdown]
# # Abrindo arquivos com Python

# %%
arquivo2 = open("arquivo2.txt", 'w')
arquivo2.close()

# %%
casa = "A casa é bonita"

arquivo_casa = open("casa.txt", "w")

# %%
import io
arquivo_casa = io.StringIO(casa)

# %%
arquivo_casa.close()

# %%
with open("arquivo3.txt", 'w') as arquivo3:
    arquivo3.write("cansei.")
