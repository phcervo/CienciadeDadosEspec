# %% [markdown]
# # Módulo de busca de página- getter

# %% [markdown]
# ## Função get_web
# Está função provê uma função  de buscar páginas na web com a seguinte assinatura.

# %%
# Função get_web
from typing import Any
import requests


def get_web(nome_pagina: str) -> Any:
    r = requests.get('https://api.github.com/events')
    codigo_fonte = r.json()
    
    return codigo_fonte

# %%
codigo = get_web('https://api.github.com/events')

# %%
print(codigo)
# Out:
# [{'id': '34040138830', 'type': 'PushEvent', 'actor': {'id': 280283, 'login': 'jalopezsuarez', 'display_login': 'jalopezsuarez', 'gravatar_id': '', 'url': 'https://api.github.com/users/jalopezsuarez', 'avatar_url': 'https://avatars.githubusercontent.com/u/280283?'}, 'repo': {'id': 729539127, 'name': 'jalopezsuarez/RaspberryTerminal24', 'url': 'https://api.github.com/repos/jalopezsuarez/RaspberryTerminal24'}, 'payload': {'repository_id': 729539127, 'push_id': 16210539225, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '5a0251f8dc3f862b804768d64197b12f0716c3a2', 'before': '8e878211743bf90c0a2de31291dc67c4fee13b5c', 'commits': [{'sha': '5a0251f8dc3f862b804768d64197b12f0716c3a2', 'author': {'email': 'jalopezsuarez@users.noreply.github.com', 'name': 'Jose Antonio Lopez'}, 'message': 'Update README.md', 'distinct': True, 'url': 'https://api.github.com/repos/jalopezsuarez/RaspberryTerminal24/commits/5a0251f8dc3f862b804768d64197b12f0716c3a2'}]}, 'public': True, 'created_at': '2023-12-09T19:51:01Z'}, {'id': '34040138838', 'type': 'PushEvent', 'actor': {'id': 93382891, 'login': 'MathiasExorde', 'display_login': 'MathiasExorde', 'gravatar_id': '', 'url': 'https://api.github.com/users/MathiasExorde', 'avatar_url': 'https://avatars.githubusercontent.com/u/93382891?'}, 'repo': {'id': 511095846, 'name': 'exorde-labs/TestnetProtocol', 'url': 'https://api.github.com/repos/exorde-labs/TestnetProtocol'}, 'payload': {'repository_id': 511095846, 'push_id': 16210539233, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '016b7abdbe607c43cc0107d3a6b6a37ba45091de', 'before': 'cc55081b50474a9a0fd97ac3084519c38540356e', 'commits': [{'sha': '016b7abdbe607c43cc0107d3a6b6a37ba45091de', 'author': {'email': '93382891+MathiasExorde@users.noreply.github.com', 'name': 'Mathias Dail'}, 'message': 'Automated update 2023-12-09-Dec-12', 'distinct': True, 'url': 'https://api.github.com/repos/exorde-labs/TestnetProtocol/commits/016b7abdbe607c43cc0107d3a6b6a37ba45091de'}]}, 'public': True, 'created_at': '2023-12-09T19:51:01Z', 'org': {'id': 64810085, 'login': 'exorde-labs', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/exorde-labs', 'avatar_url': 'https://avatars.githubusercontent.com/u/64810085?'}}, {'id': '34040138835', 'type': 'PushEvent', 'actor': {'id': 148391329, 'login': 'rebetooos', 'display_login': 'rebetooos', 'gravatar_id': '', 'url': 'https://api.github.com/users/rebetooos', 'avatar_url': 'https://avatars.githubusercontent.com/u/148391329?'}, 'repo': {'id': 706884765, 'name': 'rebetooos/test', 'url': 'https://api.github.com/repos/rebetooos/test'}, 'payload': {'repository_id': 706884765, 'push_id': 16210539230, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': 'c4c765c8a633808532b25cfb28e035035140566f', 'before': '1a2f74263707c5e93e1db5d957d767941cc0aadf', 'commits': [{'sha': 'c4c765c8a633808532b25cfb28e035035140566f', 'author': {'email': 'octocat@github.com', 'name': 'Monalisa Octocat'}, 'message': 'a new commit message', 'distinct': True, 'url': 'https://api.github.com/repos/rebetooos/test/commits/c4c765c8a633808532b25cfb28e035035140566f'}]}, 'public': True, 'created_at': '2023-12-09T19:51:01Z'}, {'id': '34040138833', 'type': 'PushEvent', 'actor': {'id': 139122098, 'login': 'Mohabdo21', 'display_login': 'Mohabdo21', 'gravatar_id': '', 'url': 'https://api.github.com/users/Mohabdo21', 'avatar_url': 'https://avatars.githubusercontent.com/u/139122098?'}, 'repo': {'id': 712052259, 'name': 'Mohabdo21/alx-higher_level_programming', 'url': 'https://api.github.com/repos/Mohabdo21/alx-higher_level_programming'}, 'payload': {'repository_id': 712052259, 'push_id': 16210539227, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/main', 'head': '4d117fd2931e0fdc42e3eed8551eed4f563c9b3f', 'before': 'bdca121195fd8e625967f60e1c1f81b1a9425df8', 'commits': [{'sha': '4d117fd2931e0fdc42e3eed8551eed4f563c9b3f', 'author': {'email': 'mohannadabdo21@hotmail.com', 'name': 'Mohabdo21'}, 'message': '7. Display #1', 'distinct': Tr ...

# %% [markdown]
# #  Treinando o uso da biblioteca Requests
# A referência está [aqui(https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
import requests

# %%
# Buscar dados no site
r = requests.get('https://api.github.com/events')
print(type(r))
# Out:
# <class 'requests.models.Response'>

# %%
# Enviar informações e gravar dados
r = requests.post('https://httpbin.org/post', data={'key': 'value'})
print(type(r))
# Out:
# <class 'requests.models.Response'>

# %%
# Conteúdo da resposta
## Podemos ler o conteúdo da resposta do servidor

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"34039774388","type":"DeleteEvent","actor":{"id":249955,"login":"SergeyZh","display_login":"SergeyZh","gravatar_id":"","url":"https://api.github.com/users/SergeyZh","avatar_url":"https://avatars.githubusercontent.com/u/249955?"},"repo":{"id":2209077,"name":"JetBrains/MPS","url":"https://api.github.com/repos/JetBrains/MPS"},"payload":{"ref":"3.0.2","ref_type":"tag","pusher_type":"user"},"public":true,"created_at":"2023-12-09T19:02:09Z","org":{"id":878437,"login":"JetBrains","gravatar_id":"","url":"https://api.github.com/orgs/JetBrains","avatar_url":"https://avatars.githubusercontent.com/u/878437?"}},{"id":"34039774362","type":"PushEvent","actor":{"id":509642,"login":"Fauxly","display_login":"Fauxly","gravatar_id":"","url":"https://api.github.com/users/Fauxly","avatar_url":"https://avatars.githubusercontent.com/u/509642?"},"repo":{"id":711214513,"name":"Fauxly/twrp_device_xiaomi_pipa","url":"https://api.github.com/repos/Fauxly/twrp_device_xiaomi_pipa"},"payload":{"repository_id":711214513,"push_id":16210314967,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"ed89d8f22911d9d5218d3909e9bff71769843b34","before":"7d94dc1fc65234310083fe146f4b7e61f2f277c2","commits":[{"sha":"ed89d8f22911d9d5218d3909e9bff71769843b34","author":{"email":"tailormoon@icloud.com","name":"Ihor"},"message":"update","distinct":true,"url":"https://api.github.com/repos/Fauxly/twrp_device_xiaomi_pipa/commits/ed89d8f22911d9d5218d3909e9bff71769843b34"}]},"public":true,"created_at":"2023-12-09T19:02:09Z"},{"id":"34039774367","type":"CreateEvent","actor":{"id":131670582,"login":"najibdevs","display_login":"najibdevs","gravatar_id":"","url":"https://api.github.com/users/najibdevs","avatar_url":"https://avatars.githubusercontent.com/u/131670582?"},"repo":{"id":729606705,"name":"najibdevs/eduford-responsiveness","url":"https://api.github.com/repos/najibdevs/eduford-responsiveness"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2023-12-09T19:02:09Z"},{"id":"34039774351","type":"PushEvent","actor":{"id":105997560,"login":"PedroHenrique65","display_login":"PedroHenrique65","gravatar_id":"","url":"https://api.github.com/users/PedroHenrique65","avatar_url":"https://avatars.githubusercontent.com/u/105997560?"},"repo":{"id":726060450,"name":"PedroHenrique65/0","url":"https://api.github.com/repos/PedroHenrique65/0"},"payload":{"repository_id":726060450,"push_id":16210314960,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"dad7e934d308043764f9f59e0773a93bf542e11f","before":"86ce79fca52cc1a317daf9af213f28e29721097c","commits":[{"sha":"dad7e934d308043764f9f59e0773a93bf542e11f","author":{"email":"105997560+PedroHenrique65@users.noreply.github.com","name":"Pedro Henrique"},"message":"Commit atualizando fable do playground","distinct":true,"url":"https://api.github.com/repos/PedroHenrique65/0/commits/dad7e934d308043764f9f59e0773a93bf542e11f"}]},"public":true,"created_at":"2023-12-09T19:02:09Z"},{"id":"34039774347","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":291729426,"name":"jsyrovy/AquaWatcher","url":"https://api.github.com/repos/jsyrovy/AquaWatcher"},"payload":{"repository_id":291729426,"push_id":16210314955,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7144454118370d707e7ba3cce453fa9e3752911c","before":"ed8439f39cba63d613735468da78b7a53d420bf8","commits":[{"sha":"7144454118370d707e7ba3cce453fa9e3752911c","author":{"email":"jiri.syrovy+github-actions@gmail.com","name":"downloader"},"message":"Add data","distinct":true,"url":"https://api.github.com/repos/jsyrovy/AquaWatcher/commits/7144454118370d707e7ba3cce453fa9e3752911c"}]},"public":true,"created_at":"2023-12-09T19:02:09Z"},{"id":"34039774353","type":"DeleteEvent","actor":{"id":18200911,"lo ...

# %%
# Serve para descobrir a codificação 
r.encoding
# Out:
# 'utf-8'

# %%
r.encoding = 'ISO-8859-1'

# %%
# Conteúdo de resposta binária

# %%
r.content
# Out:
# b'[{"id":"34039774388","type":"DeleteEvent","actor":{"id":249955,"login":"SergeyZh","display_login":"SergeyZh","gravatar_id":"","url":"https://api.github.com/users/SergeyZh","avatar_url":"https://avatars.githubusercontent.com/u/249955?"},"repo":{"id":2209077,"name":"JetBrains/MPS","url":"https://api.github.com/repos/JetBrains/MPS"},"payload":{"ref":"3.0.2","ref_type":"tag","pusher_type":"user"},"public":true,"created_at":"2023-12-09T19:02:09Z","org":{"id":878437,"login":"JetBrains","gravatar_id":"","url":"https://api.github.com/orgs/JetBrains","avatar_url":"https://avatars.githubusercontent.com/u/878437?"}},{"id":"34039774362","type":"PushEvent","actor":{"id":509642,"login":"Fauxly","display_login":"Fauxly","gravatar_id":"","url":"https://api.github.com/users/Fauxly","avatar_url":"https://avatars.githubusercontent.com/u/509642?"},"repo":{"id":711214513,"name":"Fauxly/twrp_device_xiaomi_pipa","url":"https://api.github.com/repos/Fauxly/twrp_device_xiaomi_pipa"},"payload":{"repository_id":711214513,"push_id":16210314967,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"ed89d8f22911d9d5218d3909e9bff71769843b34","before":"7d94dc1fc65234310083fe146f4b7e61f2f277c2","commits":[{"sha":"ed89d8f22911d9d5218d3909e9bff71769843b34","author":{"email":"tailormoon@icloud.com","name":"Ihor"},"message":"update","distinct":true,"url":"https://api.github.com/repos/Fauxly/twrp_device_xiaomi_pipa/commits/ed89d8f22911d9d5218d3909e9bff71769843b34"}]},"public":true,"created_at":"2023-12-09T19:02:09Z"},{"id":"34039774367","type":"CreateEvent","actor":{"id":131670582,"login":"najibdevs","display_login":"najibdevs","gravatar_id":"","url":"https://api.github.com/users/najibdevs","avatar_url":"https://avatars.githubusercontent.com/u/131670582?"},"repo":{"id":729606705,"name":"najibdevs/eduford-responsiveness","url":"https://api.github.com/repos/najibdevs/eduford-responsiveness"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2023-12-09T19:02:09Z"},{"id":"34039774351","type":"PushEvent","actor":{"id":105997560,"login":"PedroHenrique65","display_login":"PedroHenrique65","gravatar_id":"","url":"https://api.github.com/users/PedroHenrique65","avatar_url":"https://avatars.githubusercontent.com/u/105997560?"},"repo":{"id":726060450,"name":"PedroHenrique65/0","url":"https://api.github.com/repos/PedroHenrique65/0"},"payload":{"repository_id":726060450,"push_id":16210314960,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"dad7e934d308043764f9f59e0773a93bf542e11f","before":"86ce79fca52cc1a317daf9af213f28e29721097c","commits":[{"sha":"dad7e934d308043764f9f59e0773a93bf542e11f","author":{"email":"105997560+PedroHenrique65@users.noreply.github.com","name":"Pedro Henrique"},"message":"Commit atualizando fable do playground","distinct":true,"url":"https://api.github.com/repos/PedroHenrique65/0/commits/dad7e934d308043764f9f59e0773a93bf542e11f"}]},"public":true,"created_at":"2023-12-09T19:02:09Z"},{"id":"34039774347","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":291729426,"name":"jsyrovy/AquaWatcher","url":"https://api.github.com/repos/jsyrovy/AquaWatcher"},"payload":{"repository_id":291729426,"push_id":16210314955,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7144454118370d707e7ba3cce453fa9e3752911c","before":"ed8439f39cba63d613735468da78b7a53d420bf8","commits":[{"sha":"7144454118370d707e7ba3cce453fa9e3752911c","author":{"email":"jiri.syrovy+github-actions@gmail.com","name":"downloader"},"message":"Add data","distinct":true,"url":"https://api.github.com/repos/jsyrovy/AquaWatcher/commits/7144454118370d707e7ba3cce453fa9e3752911c"}]},"public":true,"created_at":"2023-12-09T19:02:09Z"},{"id":"34039774353","type":"DeleteEvent","actor":{"id":18200911,"l ...

# %%
# Criar uma imagem a partir de dados binários retornados por uma solicitação

# %%
from PIL import Image
from io import BytesIO

i = Image.open(BytesIO(r.content))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# c:\Users\phcer\Downloads\CienciadeDadosEspec-main\CienciadeDadosEspec-main\Projeto5\test\test_getter.ipynb Cell 16 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/phcer/Downloads/CienciadeDadosEspec-main/CienciadeDadosEspec-main/Projeto5/test/test_getter.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> from PIL import Image
#       <a href='vscode-notebook-cell:/c%3A/Users/phcer/Downloads/CienciadeDadosEspec-main/CienciadeDadosEspec-main/Projeto5/test/test_getter.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> from io import BytesIO
# ----> <a href='vscode-notebook-cell:/c%3A/Users/phcer/Downloads/CienciadeDadosEspec-main/CienciadeDadosEspec-main/Projeto5/test/test_getter.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> i = Image.open(BytesIO(r.content))
#
# File c:\Users\phcer\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3186, in open(fp, mode, formats)
#    3184 for message in accept_warnings:
#    3185     warnings.warn(message)
# -> 3186 raise UnidentifiedImageError(
#    3187     "cannot identify image file %r" % (filename if filename else fp)
#    3188 )
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x000001D8B2ECBAB0>

# %%
# Conteúdo de resposta JSON
## Possui também um decodificador JSON interno.
import requests
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '34039776076',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 530522206,
#    'name': 'n00bcodr/formula-standings',
#    'url': 'https://api.github.com/repos/n00bcodr/formula-standings'},
#   'payload': {'repository_id': 530522206,
#    'push_id': 16210316168,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '865fafb99970b2968bb467a7dc67bf83248d4a5d',
#    'before': 'd64720ba9354356b5c54b9f166ae0e17af3103ea',
#    'commits': [{'sha': '865fafb99970b2968bb467a7dc67bf83248d4a5d',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'auto-update table data',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/n00bcodr/formula-standings/commits/865fafb99970b2968bb467a7dc67bf83248d4a5d'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776054',
#   'type': 'PushEvent',
#   'actor': {'id': 86872229,
#    'login': 'MAbdelkader94',
#    'display_login': 'MAbdelkader94',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MAbdelkader94',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86872229?'},
#   'repo': {'id': 708224527,
#    'name': 'MAbdelkader94/MAbdelkader94.github.io',
#    'url': 'https://api.github.com/repos/MAbdelkader94/MAbdelkader94.github.io'},
#   'payload': {'repository_id': 708224527,
#    'push_id': 16210316153,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9fa63e331d5dbd15eaa22d066ed93f94a375abb3',
#    'before': '19620262b509af15e86177d79b9c90242f5a8d0a',
#    'commits': [{'sha': '9fa63e331d5dbd15eaa22d066ed93f94a375abb3',
#      'author': {'email': 'achraftounsi70@gmail.com\\n',
#       'name': 'achraftounsi'},
#      'message': '13:50 12/09/2023',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MAbdelkader94/MAbdelkader94.github.io/commits/9fa63e331d5dbd15eaa22d066ed93f94a375abb3'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776045',
#   'type': 'PushEvent',
#   'actor': {'id': 27142376,
#    'login': 'marcoantonio40',
#    'display_login': 'marcoantonio40',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marcoantonio40',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27142376?'},
#   'repo': {'id': 711280831,
#    'name': 'marcoantonio40/atelier_control',
#    'url': 'https://api.github.com/repos/marcoantonio40/atelier_control'},
#   'payload': {'repository_id': 711280831,
#    'push_id': 16210316146,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '17db24dfd348785a171419b7982db39650039f7c',
#    'before': '693d4335ba6839f5e0a4b71bb01b60efd6601193',
#    'commits': [{'sha': '17db24dfd348785a171419b7982db39650039f7c',
#      'author': {'email': 'marcoudi40@gmail.com', 'name': 'marcoantonio40'},
#      'message': 'Added config in gitignore',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/marcoantonio40/atelier_control/commits/17db24dfd348785a171419b7982db39650039f7c'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776048',
#   'type': 'PushEvent',
#   'actor': {'id': 13970203,
#    'login': 'baileyholl',
#    'display_login': 'baileyholl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baileyholl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13970203?'},
#   'repo': {'id': 483500806,
#    'name': 'dkmk100/Ars-Nouveau',
#    'url': 'https://api.github.com/repos/dkmk100/Ars-Nouveau'},
#   'payload': {'repository_id': 483500806,
#    'push_id': 16210316150,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/pop-context',
#    'head': 'f5d11e3d18c84f45fcc9ae635dd43511985ebe60',
#    'before': '37f2dff6fe03fe46db1346188674beb9d75f90c5',
#    'commits': [{'sha': 'f5d11e3d18c84f45fcc9ae635dd43511985ebe60',
#      'author': {'email': 'baileyholl@gmail.com',
#       'name': 'Bailey Hollingsworth'},
#      'message': 'temp disable validator',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dkmk100/Ars-Nouveau/commits/f5d11e3d18c84f45fcc9ae635dd43511985ebe60'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776064',
#   'type': 'PushEvent',
#   'actor': {'id': 84812593,
#    'login': 'alexanderwolz',
#    'display_login': 'alexanderwolz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexanderwolz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84812593?'},
#   'repo': {'id': 729579909,
#    'name': 'alexanderwolz/android_device_whaleshark',
#    'url': 'https://api.github.com/repos/alexanderwolz/android_device_whaleshark'},
#   'payload': {'repository_id': 729579909,
#    'push_id': 16210316163,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ad1d255e1c9bf935490a6e57342e472ec70a482a',
#    'before': 'd3fb0779eb819dabcc1bac836c1f260851f37164',
#    'commits': [{'sha': 'ad1d255e1c9bf935490a6e57342e472ec70a482a',
#      'author': {'email': 'mail@alexanderwolz.de', 'name': 'Alexander Wolz'},
#      'message': 'added Readme and first successful build',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alexanderwolz/android_device_whaleshark/commits/ad1d255e1c9bf935490a6e57342e472ec70a482a'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776041',
#   'type': 'PushEvent',
#   'actor': {'id': 44421559,
#    'login': 'colebot',
#    'display_login': 'colebot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/colebot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44421559?'},
#   'repo': {'id': 48925473,
#    'name': 'colemickens/nixcfg',
#    'url': 'https://api.github.com/repos/colemickens/nixcfg'},
#   'payload': {'repository_id': 48925473,
#    'push_id': 16210316148,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main-next-wip',
#    'head': '45dff85e10cc5ba6773e81a82d9086a13f0d8bfd',
#    'before': '6fb8877a436cc4fa737a0af190841b9ea7098779',
#    'commits': [{'sha': '45dff85e10cc5ba6773e81a82d9086a13f0d8bfd',
#      'author': {'email': 'cole.mickens+colebot@gmail.com',
#       'name': 'Cole Botkens'},
#      'message': 'rio: unstable-2023-11-29 -> unstable-2023-12-09\n\nDiff: https://github.com/raphamorim/rio/compare/077bf080f6e4268203b5258025cadabd80fd1736...be2c64a05a700b12cbc59f4632c78755143b61e4\n\nChangelog: https://github.com/raphamorim/rio/blob/vunstable-2023-12-09/CHANGELOG.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/colemickens/nixcfg/commits/45dff85e10cc5ba6773e81a82d9086a13f0d8bfd'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776038',
#   'type': 'PushEvent',
#   'actor': {'id': 51961410,
#    'login': 'SanaurAsif',
#    'display_login': 'SanaurAsif',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SanaurAsif',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51961410?'},
#   'repo': {'id': 729247209,
#    'name': 'SanaurAsif/share',
#    'url': 'https://api.github.com/repos/SanaurAsif/share'},
#   'payload': {'repository_id': 729247209,
#    'push_id': 16210316145,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3b87d4711b37c1f529d0f5bb4cb0491a7fcc42f3',
#    'before': '8629415eb4dcea2d258fd6f9dfb6b14856737ab9',
#    'commits': [{'sha': '3b87d4711b37c1f529d0f5bb4cb0491a7fcc42f3',
#      'author': {'email': 'sanaurasif2@gmail.com', 'name': 'Sanaur Asif'},
#      'message': 'Update uids.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SanaurAsif/share/commits/3b87d4711b37c1f529d0f5bb4cb0491a7fcc42f3'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776035',
#   'type': 'PushEvent',
#   'actor': {'id': 120330808,
#    'login': 'AadiDreams',
#    'display_login': 'AadiDreams',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AadiDreams',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120330808?'},
#   'repo': {'id': 717817492,
#    'name': 'AadiDreams/CODSOFT',
#    'url': 'https://api.github.com/repos/AadiDreams/CODSOFT'},
#   'payload': {'repository_id': 717817492,
#    'push_id': 16210316144,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '405262cc67d423410447e4f7190f0670f18ca649',
#    'before': '2c29b5f33f2cab197109501c8aae94906ed30349',
#    'commits': [{'sha': '957d8e5666768b19892243837a6ca771f2fae323',
#      'author': {'email': '120330808+AadiDreams@users.noreply.github.com',
#       'name': 'AADITHYA V ANAND'},
#      'message': 'Update README.md\n\nadded link for task 3',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/AadiDreams/CODSOFT/commits/957d8e5666768b19892243837a6ca771f2fae323'},
#     {'sha': '405262cc67d423410447e4f7190f0670f18ca649',
#      'author': {'email': '120330808+AadiDreams@users.noreply.github.com',
#       'name': 'AADITHYA V ANAND'},
#      'message': 'Merge pull request #8 from AadiDreams/AadiDreams-patch-6\n\nUpdate README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AadiDreams/CODSOFT/commits/405262cc67d423410447e4f7190f0670f18ca649'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776053',
#   'type': 'DeleteEvent',
#   'actor': {'id': 45291656,
#    'login': 'oswaldobapvicjr',
#    'display_login': 'oswaldobapvicjr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/oswaldobapvicjr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45291656?'},
#   'repo': {'id': 524247697,
#    'name': 'oswaldobapvicjr/jsonmerge',
#    'url': 'https://api.github.com/repos/oswaldobapvicjr/jsonmerge'},
#   'payload': {'ref': 'snyk-upgrade-e526cb1f779ab64fdf166d2b45048d09',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776063',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 130296385,
#    'login': 'siarheishut',
#    'display_login': 'siarheishut',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/siarheishut',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/130296385?'},
#   'repo': {'id': 627137923,
#    'name': 'siarheishut/route_manager',
#    'url': 'https://api.github.com/repos/siarheishut/route_manager'},
#   'payload': {'action': 'closed',
#    'number': 107,
#    'pull_request': {'url': 'https://api.github.com/repos/siarheishut/route_manager/pulls/107',
#     'id': 1637315776,
#     'node_id': 'PR_kwDOJWFdg85hl3TA',
#     'html_url': 'https://github.com/siarheishut/route_manager/pull/107',
#     'diff_url': 'https://github.com/siarheishut/route_manager/pull/107.diff',
#     'patch_url': 'https://github.com/siarheishut/route_manager/pull/107.patch',
#     'issue_url': 'https://api.github.com/repos/siarheishut/route_manager/issues/107',
#     'number': 107,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Change StopCoords alias.',
#     'user': {'login': 'siarheishut',
#      'id': 130296385,
#      'node_id': 'U_kgDOB8QqQQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/130296385?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/siarheishut',
#      'html_url': 'https://github.com/siarheishut',
#      'followers_url': 'https://api.github.com/users/siarheishut/followers',
#      'following_url': 'https://api.github.com/users/siarheishut/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/siarheishut/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/siarheishut/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/siarheishut/subscriptions',
#      'organizations_url': 'https://api.github.com/users/siarheishut/orgs',
#      'repos_url': 'https://api.github.com/users/siarheishut/repos',
#      'events_url': 'https://api.github.com/users/siarheishut/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/siarheishut/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Change StopCoords to StopPoints in MapRenderer, because it better reflects the assignment. \r\nAdd alias StopCoords and use it in coords_converter module in order to avoid coping fields, that won't be used.\r\nFix tests.",
#     'created_at': '2023-12-09T16:55:10Z',
#     'updated_at': '2023-12-09T19:02:23Z',
#     'closed_at': '2023-12-09T19:02:23Z',
#     'merged_at': '2023-12-09T19:02:23Z',
#     'merge_commit_sha': 'dee6b194686a2bf19ec3fe9247606574d1196299',
#     'assignee': {'login': 'siarheishut',
#      'id': 130296385,
#      'node_id': 'U_kgDOB8QqQQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/130296385?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/siarheishut',
#      'html_url': 'https://github.com/siarheishut',
#      'followers_url': 'https://api.github.com/users/siarheishut/followers',
#      'following_url': 'https://api.github.com/users/siarheishut/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/siarheishut/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/siarheishut/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/siarheishut/subscriptions',
#      'organizations_url': 'https://api.github.com/users/siarheishut/orgs',
#      'repos_url': 'https://api.github.com/users/siarheishut/repos',
#      'events_url': 'https://api.github.com/users/siarheishut/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/siarheishut/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'siarheishut',
#       'id': 130296385,
#       'node_id': 'U_kgDOB8QqQQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/130296385?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/siarheishut',
#       'html_url': 'https://github.com/siarheishut',
#       'followers_url': 'https://api.github.com/users/siarheishut/followers',
#       'following_url': 'https://api.github.com/users/siarheishut/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/siarheishut/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/siarheishut/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/siarheishut/subscriptions',
#       'organizations_url': 'https://api.github.com/users/siarheishut/orgs',
#       'repos_url': 'https://api.github.com/users/siarheishut/repos',
#       'events_url': 'https://api.github.com/users/siarheishut/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/siarheishut/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/siarheishut/route_manager/pulls/107/commits',
#     'review_comments_url': 'https://api.github.com/repos/siarheishut/route_manager/pulls/107/comments',
#     'review_comment_url': 'https://api.github.com/repos/siarheishut/route_manager/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/siarheishut/route_manager/issues/107/comments',
#     'statuses_url': 'https://api.github.com/repos/siarheishut/route_manager/statuses/72517f3daf445467c4be7cac63525c9faf53d647',
#     'head': {'label': 'siarheishut:change_stop_coords_alias',
#      'ref': 'change_stop_coords_alias',
#      'sha': '72517f3daf445467c4be7cac63525c9faf53d647',
#      'user': {'login': 'siarheishut',
#       'id': 130296385,
#       'node_id': 'U_kgDOB8QqQQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/130296385?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/siarheishut',
#       'html_url': 'https://github.com/siarheishut',
#       'followers_url': 'https://api.github.com/users/siarheishut/followers',
#       'following_url': 'https://api.github.com/users/siarheishut/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/siarheishut/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/siarheishut/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/siarheishut/subscriptions',
#       'organizations_url': 'https://api.github.com/users/siarheishut/orgs',
#       'repos_url': 'https://api.github.com/users/siarheishut/repos',
#       'events_url': 'https://api.github.com/users/siarheishut/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/siarheishut/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 627137923,
#       'node_id': 'R_kgDOJWFdgw',
#       'name': 'route_manager',
#       'full_name': 'siarheishut/route_manager',
#       'private': False,
#       'owner': {'login': 'siarheishut',
#        'id': 130296385,
#        'node_id': 'U_kgDOB8QqQQ',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/130296385?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/siarheishut',
#        'html_url': 'https://github.com/siarheishut',
#        'followers_url': 'https://api.github.com/users/siarheishut/followers',
#        'following_url': 'https://api.github.com/users/siarheishut/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/siarheishut/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/siarheishut/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/siarheishut/subscriptions',
#        'organizations_url': 'https://api.github.com/users/siarheishut/orgs',
#        'repos_url': 'https://api.github.com/users/siarheishut/repos',
#        'events_url': 'https://api.github.com/users/siarheishut/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/siarheishut/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/siarheishut/route_manager',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/siarheishut/route_manager',
#       'forks_url': 'https://api.github.com/repos/siarheishut/route_manager/forks',
#       'keys_url': 'https://api.github.com/repos/siarheishut/route_manager/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/siarheishut/route_manager/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/siarheishut/route_manager/teams',
#       'hooks_url': 'https://api.github.com/repos/siarheishut/route_manager/hooks',
#       'issue_events_url': 'https://api.github.com/repos/siarheishut/route_manager/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/siarheishut/route_manager/events',
#       'assignees_url': 'https://api.github.com/repos/siarheishut/route_manager/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/siarheishut/route_manager/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/siarheishut/route_manager/tags',
#       'blobs_url': 'https://api.github.com/repos/siarheishut/route_manager/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/siarheishut/route_manager/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/siarheishut/route_manager/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/siarheishut/route_manager/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/siarheishut/route_manager/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/siarheishut/route_manager/languages',
#       'stargazers_url': 'https://api.github.com/repos/siarheishut/route_manager/stargazers',
#       'contributors_url': 'https://api.github.com/repos/siarheishut/route_manager/contributors',
#       'subscribers_url': 'https://api.github.com/repos/siarheishut/route_manager/subscribers',
#       'subscription_url': 'https://api.github.com/repos/siarheishut/route_manager/subscription',
#       'commits_url': 'https://api.github.com/repos/siarheishut/route_manager/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/siarheishut/route_manager/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/siarheishut/route_manager/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/siarheishut/route_manager/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/siarheishut/route_manager/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/siarheishut/route_manager/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/siarheishut/route_manager/merges',
#       'archive_url': 'https://api.github.com/repos/siarheishut/route_manager/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/siarheishut/route_manager/downloads',
#       'issues_url': 'https://api.github.com/repos/siarheishut/route_manager/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/siarheishut/route_manager/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/siarheishut/route_manager/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/siarheishut/route_manager/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/siarheishut/route_manager/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/siarheishut/route_manager/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/siarheishut/route_manager/deployments',
#       'created_at': '2023-04-12T21:32:07Z',
#       'updated_at': '2023-05-26T02:57:40Z',
#       'pushed_at': '2023-12-09T19:02:23Z',
#       'git_url': 'git://github.com/siarheishut/route_manager.git',
#       'ssh_url': 'git@github.com:siarheishut/route_manager.git',
#       'clone_url': 'https://github.com/siarheishut/route_manager.git',
#       'svn_url': 'https://github.com/siarheishut/route_manager',
#       'homepage': None,
#       'size': 171,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'siarheishut:dev',
#      'ref': 'dev',
#      'sha': 'd1dd8b07126b491d19f93e208da7e0dfd4a1ff0f',
#      'user': {'login': 'siarheishut',
#       'id': 130296385,
#       'node_id': 'U_kgDOB8QqQQ',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/130296385?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/siarheishut',
#       'html_url': 'https://github.com/siarheishut',
#       'followers_url': 'https://api.github.com/users/siarheishut/followers',
#       'following_url': 'https://api.github.com/users/siarheishut/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/siarheishut/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/siarheishut/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/siarheishut/subscriptions',
#       'organizations_url': 'https://api.github.com/users/siarheishut/orgs',
#       'repos_url': 'https://api.github.com/users/siarheishut/repos',
#       'events_url': 'https://api.github.com/users/siarheishut/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/siarheishut/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 627137923,
#       'node_id': 'R_kgDOJWFdgw',
#       'name': 'route_manager',
#       'full_name': 'siarheishut/route_manager',
#       'private': False,
#       'owner': {'login': 'siarheishut',
#        'id': 130296385,
#        'node_id': 'U_kgDOB8QqQQ',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/130296385?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/siarheishut',
#        'html_url': 'https://github.com/siarheishut',
#        'followers_url': 'https://api.github.com/users/siarheishut/followers',
#        'following_url': 'https://api.github.com/users/siarheishut/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/siarheishut/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/siarheishut/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/siarheishut/subscriptions',
#        'organizations_url': 'https://api.github.com/users/siarheishut/orgs',
#        'repos_url': 'https://api.github.com/users/siarheishut/repos',
#        'events_url': 'https://api.github.com/users/siarheishut/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/siarheishut/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/siarheishut/route_manager',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/siarheishut/route_manager',
#       'forks_url': 'https://api.github.com/repos/siarheishut/route_manager/forks',
#       'keys_url': 'https://api.github.com/repos/siarheishut/route_manager/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/siarheishut/route_manager/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/siarheishut/route_manager/teams',
#       'hooks_url': 'https://api.github.com/repos/siarheishut/route_manager/hooks',
#       'issue_events_url': 'https://api.github.com/repos/siarheishut/route_manager/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/siarheishut/route_manager/events',
#       'assignees_url': 'https://api.github.com/repos/siarheishut/route_manager/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/siarheishut/route_manager/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/siarheishut/route_manager/tags',
#       'blobs_url': 'https://api.github.com/repos/siarheishut/route_manager/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/siarheishut/route_manager/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/siarheishut/route_manager/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/siarheishut/route_manager/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/siarheishut/route_manager/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/siarheishut/route_manager/languages',
#       'stargazers_url': 'https://api.github.com/repos/siarheishut/route_manager/stargazers',
#       'contributors_url': 'https://api.github.com/repos/siarheishut/route_manager/contributors',
#       'subscribers_url': 'https://api.github.com/repos/siarheishut/route_manager/subscribers',
#       'subscription_url': 'https://api.github.com/repos/siarheishut/route_manager/subscription',
#       'commits_url': 'https://api.github.com/repos/siarheishut/route_manager/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/siarheishut/route_manager/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/siarheishut/route_manager/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/siarheishut/route_manager/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/siarheishut/route_manager/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/siarheishut/route_manager/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/siarheishut/route_manager/merges',
#       'archive_url': 'https://api.github.com/repos/siarheishut/route_manager/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/siarheishut/route_manager/downloads',
#       'issues_url': 'https://api.github.com/repos/siarheishut/route_manager/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/siarheishut/route_manager/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/siarheishut/route_manager/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/siarheishut/route_manager/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/siarheishut/route_manager/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/siarheishut/route_manager/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/siarheishut/route_manager/deployments',
#       'created_at': '2023-04-12T21:32:07Z',
#       'updated_at': '2023-05-26T02:57:40Z',
#       'pushed_at': '2023-12-09T19:02:23Z',
#       'git_url': 'git://github.com/siarheishut/route_manager.git',
#       'ssh_url': 'git@github.com:siarheishut/route_manager.git',
#       'clone_url': 'https://github.com/siarheishut/route_manager.git',
#       'svn_url': 'https://github.com/siarheishut/route_manager',
#       'homepage': None,
#       'size': 171,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/siarheishut/route_manager/pulls/107'},
#      'html': {'href': 'https://github.com/siarheishut/route_manager/pull/107'},
#      'issue': {'href': 'https://api.github.com/repos/siarheishut/route_manager/issues/107'},
#      'comments': {'href': 'https://api.github.com/repos/siarheishut/route_manager/issues/107/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/siarheishut/route_manager/pulls/107/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/siarheishut/route_manager/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/siarheishut/route_manager/pulls/107/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/siarheishut/route_manager/statuses/72517f3daf445467c4be7cac63525c9faf53d647'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'siarheishut',
#      'id': 130296385,
#      'node_id': 'U_kgDOB8QqQQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/130296385?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/siarheishut',
#      'html_url': 'https://github.com/siarheishut',
#      'followers_url': 'https://api.github.com/users/siarheishut/followers',
#      'following_url': 'https://api.github.com/users/siarheishut/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/siarheishut/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/siarheishut/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/siarheishut/subscriptions',
#      'organizations_url': 'https://api.github.com/users/siarheishut/orgs',
#      'repos_url': 'https://api.github.com/users/siarheishut/repos',
#      'events_url': 'https://api.github.com/users/siarheishut/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/siarheishut/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 2,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 56,
#     'deletions': 48,
#     'changed_files': 6}},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776012',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 528758875,
#    'name': 'muath-ye/muath-ye',
#    'url': 'https://api.github.com/repos/muath-ye/muath-ye'},
#   'payload': {'repository_id': 528758875,
#    'push_id': 16210316136,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c71e736fe87cddd4a89fcd4a3a97042cd915268e',
#    'before': '5c3669e278029624c0d95245437869fc428f6d45',
#    'commits': [{'sha': 'c71e736fe87cddd4a89fcd4a3a97042cd915268e',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update github-metrics.svg - [Skip GitHub Action]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/muath-ye/muath-ye/commits/c71e736fe87cddd4a89fcd4a3a97042cd915268e'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776037',
#   'type': 'PushEvent',
#   'actor': {'id': 284315,
#    'login': 'karindalziel',
#    'display_login': 'karindalziel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/karindalziel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/284315?'},
#   'repo': {'id': 46871533,
#    'name': 'whitmanarchive/whitman-correspondence',
#    'url': 'https://api.github.com/repos/whitmanarchive/whitman-correspondence'},
#   'payload': {'repository_id': 46871533,
#    'push_id': 16210316143,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'f0ae8411c8bbeec5406755e6e6230fe5c1b4d790',
#    'before': 'ebd676a1757cb9498bfc7e3d315cd8e30283975f',
#    'commits': [{'sha': 'a602f73b932e06f8dcc6606135e7fb94c73bb963',
#      'author': {'email': 'kdalziel2@unl.edu', 'name': 'Karin Dalziel'},
#      'message': 'fixed links',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/whitmanarchive/whitman-correspondence/commits/a602f73b932e06f8dcc6606135e7fb94c73bb963'},
#     {'sha': 'f0ae8411c8bbeec5406755e6e6230fe5c1b4d790',
#      'author': {'email': 'karindalziel@users.noreply.github.com',
#       'name': 'Karin Dalziel'},
#      'message': 'Merge pull request #14 from whitmanarchive/metadata\n\nfixed links',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/whitmanarchive/whitman-correspondence/commits/f0ae8411c8bbeec5406755e6e6230fe5c1b4d790'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z',
#   'org': {'id': 12240682,
#    'login': 'whitmanarchive',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/whitmanarchive',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12240682?'}},
#  {'id': '34039776034',
#   'type': 'PushEvent',
#   'actor': {'id': 146520663,
#    'login': 'Madalievnkx',
#    'display_login': 'Madalievnkx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Madalievnkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/146520663?'},
#   'repo': {'id': 729606854,
#    'name': 'Madalievnkx/DeBomber',
#    'url': 'https://api.github.com/repos/Madalievnkx/DeBomber'},
#   'payload': {'repository_id': 729606854,
#    'push_id': 16210316149,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3b4144add3772eec20f65e9340a209e8407ee150',
#    'before': 'a5aabebbe1be5688fe609a822dad89fac245a4c9',
#    'commits': [{'sha': '3b4144add3772eec20f65e9340a209e8407ee150',
#      'author': {'email': '146520663+Madalievnkx@users.noreply.github.com',
#       'name': 'Madalievnkx'},
#      'message': 'update file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Madalievnkx/DeBomber/commits/3b4144add3772eec20f65e9340a209e8407ee150'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776024',
#   'type': 'PushEvent',
#   'actor': {'id': 44520229,
#    'login': 'ClozerUK',
#    'display_login': 'ClozerUK',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ClozerUK',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44520229?'},
#   'repo': {'id': 460557612,
#    'name': 'ClozerUK/PixelFiles',
#    'url': 'https://api.github.com/repos/ClozerUK/PixelFiles'},
#   'payload': {'repository_id': 460557612,
#    'push_id': 16210316141,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7c6e318ef3459a9388d7472769a9d94453133dca',
#    'before': 'b8d00ccd5f08d7e7be4c8a3b09f11d8da945b29c',
#    'commits': [{'sha': '7c6e318ef3459a9388d7472769a9d94453133dca',
#      'author': {'email': '44520229+ClozerUK@users.noreply.github.com',
#       'name': 'ClozerUK'},
#      'message': 'Add new words\n\nAdd new words',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ClozerUK/PixelFiles/commits/7c6e318ef3459a9388d7472769a9d94453133dca'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776046',
#   'type': 'CreateEvent',
#   'actor': {'id': 27542393,
#    'login': 'locmai',
#    'display_login': 'locmai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/locmai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27542393?'},
#   'repo': {'id': 338411152,
#    'name': 'locmai/humble',
#    'url': 'https://api.github.com/repos/locmai/humble'},
#   'payload': {'ref': 'v0.6.0',
#    'ref_type': 'tag',
#    'master_branch': 'main',
#    'description': 'Just a humble project',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776026',
#   'type': 'PushEvent',
#   'actor': {'id': 332954,
#    'login': 'trossr32',
#    'display_login': 'trossr32',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/trossr32',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/332954?'},
#   'repo': {'id': 625268952,
#    'name': 'trossr32/rob-green-engineering',
#    'url': 'https://api.github.com/repos/trossr32/rob-green-engineering'},
#   'payload': {'repository_id': 625268952,
#    'push_id': 16210316139,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dotnet-outdated',
#    'head': 'd71f1c1aa0046261a105a31762f0a4cb40156436',
#    'before': '0739cb59299c522d12f542208bd71850781a7c6f',
#    'commits': [{'sha': 'd71f1c1aa0046261a105a31762f0a4cb40156436',
#      'author': {'email': 'rob@robgreen.me', 'name': 'Rob Green'},
#      'message': 'Update outdated.ps1',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/trossr32/rob-green-engineering/commits/d71f1c1aa0046261a105a31762f0a4cb40156436'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776002',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 472125945,
#    'name': 'Slatyo/Slatyo',
#    'url': 'https://api.github.com/repos/Slatyo/Slatyo'},
#   'payload': {'repository_id': 472125945,
#    'push_id': 16210316126,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e5492bd06345f1dd9b5bd7e4c7f2d22a4d51fb2f',
#    'before': '5084ffdd960df2a79bcf701ebef2438d33875f64',
#    'commits': [{'sha': 'e5492bd06345f1dd9b5bd7e4c7f2d22a4d51fb2f',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update github-metrics.svg - [Skip GitHub Action]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Slatyo/Slatyo/commits/e5492bd06345f1dd9b5bd7e4c7f2d22a4d51fb2f'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776011',
#   'type': 'PushEvent',
#   'actor': {'id': 146520663,
#    'login': 'Madalievnkx',
#    'display_login': 'Madalievnkx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Madalievnkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/146520663?'},
#   'repo': {'id': 729606854,
#    'name': 'Madalievnkx/DeBomber',
#    'url': 'https://api.github.com/repos/Madalievnkx/DeBomber'},
#   'payload': {'repository_id': 729606854,
#    'push_id': 16210316133,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a5aabebbe1be5688fe609a822dad89fac245a4c9',
#    'before': 'd907613f1e0543bc4bafd7164c0685c77d4c859c',
#    'commits': [{'sha': 'a5aabebbe1be5688fe609a822dad89fac245a4c9',
#      'author': {'email': '146520663+Madalievnkx@users.noreply.github.com',
#       'name': 'Madalievnkx'},
#      'message': 'update file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Madalievnkx/DeBomber/commits/a5aabebbe1be5688fe609a822dad89fac245a4c9'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776008',
#   'type': 'PushEvent',
#   'actor': {'id': 40665208,
#    'login': 'Vladikasik',
#    'display_login': 'Vladikasik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Vladikasik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40665208?'},
#   'repo': {'id': 346160126,
#    'name': 'Vladikasik/statistic',
#    'url': 'https://api.github.com/repos/Vladikasik/statistic'},
#   'payload': {'repository_id': 346160126,
#    'push_id': 16210316132,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '59b1aca7af899b122e2d89f00da25a36b9b8c9b5',
#    'before': '1eb97eeadb9675f86cfa53882f6184a0a5b7f759',
#    'commits': [{'sha': '59b1aca7af899b122e2d89f00da25a36b9b8c9b5',
#      'author': {'email': 'vladislav.ainshtein@gmail.com',
#       'name': 'vladikasik'},
#      'message': 'test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Vladikasik/statistic/commits/59b1aca7af899b122e2d89f00da25a36b9b8c9b5'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039776010',
#   'type': 'PushEvent',
#   'actor': {'id': 67713433,
#    'login': 'vp-en',
#    'display_login': 'vp-en',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vp-en',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67713433?'},
#   'repo': {'id': 706168474,
#    'name': 'vp-en/qflood',
#    'url': 'https://api.github.com/repos/vp-en/qflood'},
#   'payload': {'repository_id': 706168474,
#    'push_id': 16210316130,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/nightly',
#    'head': 'a6bc91376da4ffbab2159c1995140568fe493dfe',
#    'before': '582111c8d687b47e6771657e361a14b3cf3ca1b7',
#    'commits': [{'sha': 'a6bc91376da4ffbab2159c1995140568fe493dfe',
#      'author': {'email': 'vp-en@users.noreply.github.com', 'name': 'vp-en'},
#      'message': 'Version update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vp-en/qflood/commits/a6bc91376da4ffbab2159c1995140568fe493dfe'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039775998',
#   'type': 'WatchEvent',
#   'actor': {'id': 101289752,
#    'login': 'KeennyyW',
#    'display_login': 'KeennyyW',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KeennyyW',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101289752?'},
#   'repo': {'id': 608660340,
#    'name': 'windows93dotnet/sys42',
#    'url': 'https://api.github.com/repos/windows93dotnet/sys42'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z',
#   'org': {'id': 127446791,
#    'login': 'windows93dotnet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/windows93dotnet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/127446791?'}},
#  {'id': '34039775974',
#   'type': 'PushEvent',
#   'actor': {'id': 145666288,
#    'login': 'angelinacherkashina',
#    'display_login': 'angelinacherkashina',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/angelinacherkashina',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/145666288?'},
#   'repo': {'id': 697817940,
#    'name': 'angelinacherkashina/study_2023-2024_arc-pc',
#    'url': 'https://api.github.com/repos/angelinacherkashina/study_2023-2024_arc-pc'},
#   'payload': {'repository_id': 697817940,
#    'push_id': 16210316115,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '66c677988f28c89706b5e7563d1ad52f67fff1d9',
#    'before': '2e8d4c0871a5baadf184b4c9b7d06406302b8bdc',
#    'commits': [{'sha': '66c677988f28c89706b5e7563d1ad52f67fff1d9',
#      'author': {'email': '145666288+angelinacherkashina@users.noreply.github.com',
#       'name': 'angelinacherkashina'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/angelinacherkashina/study_2023-2024_arc-pc/commits/66c677988f28c89706b5e7563d1ad52f67fff1d9'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039775988',
#   'type': 'PushEvent',
#   'actor': {'id': 35825255,
#    'login': 'Icirus',
#    'display_login': 'Icirus',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Icirus',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35825255?'},
#   'repo': {'id': 727012013,
#    'name': 'Icirus/GrimCompany',
#    'url': 'https://api.github.com/repos/Icirus/GrimCompany'},
#   'payload': {'repository_id': 727012013,
#    'push_id': 16210316120,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': 'dcb20690bcb5a381e5b9f01c6ea0225b5d1b79b5',
#    'before': '7fb6d43ebf1940a2b22bce219c3a80fe32fc4613',
#    'commits': [{'sha': '1cbf9ab82ff95cbfef06320fece2ceb45340bd2b',
#      'author': {'email': 'bigmac70@gmail.com', 'name': 'Icirus'},
#      'message': 'updated rank names.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Icirus/GrimCompany/commits/1cbf9ab82ff95cbfef06320fece2ceb45340bd2b'},
#     {'sha': 'dcb20690bcb5a381e5b9f01c6ea0225b5d1b79b5',
#      'author': {'email': 'bigmac70@gmail.com', 'name': 'Icirus'},
#      'message': 'rebuilt for prod',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Icirus/GrimCompany/commits/dcb20690bcb5a381e5b9f01c6ea0225b5d1b79b5'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039775996',
#   'type': 'PushEvent',
#   'actor': {'id': 89993250,
#    'login': 'Had-rean',
#    'display_login': 'Had-rean',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Had-rean',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89993250?'},
#   'repo': {'id': 658870126,
#    'name': 'Your-Campaign/your-campaign.github.io',
#    'url': 'https://api.github.com/repos/Your-Campaign/your-campaign.github.io'},
#   'payload': {'repository_id': 658870126,
#    'push_id': 16210316124,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0c5b64a6cd80c15c32829d26e3602cdcd12aa808',
#    'before': '74a87d20237c1c734b676083893ebdcc426f255c',
#    'commits': [{'sha': '0c5b64a6cd80c15c32829d26e3602cdcd12aa808',
#      'author': {'email': 'delphi72@freenet.de', 'name': 'Had-rean'},
#      'message': 'second try',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Your-Campaign/your-campaign.github.io/commits/0c5b64a6cd80c15c32829d26e3602cdcd12aa808'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z',
#   'org': {'id': 137817069,
#    'login': 'Your-Campaign',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Your-Campaign',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/137817069?'}},
#  {'id': '34039775975',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 284315,
#    'login': 'karindalziel',
#    'display_login': 'karindalziel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/karindalziel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/284315?'},
#   'repo': {'id': 46871533,
#    'name': 'whitmanarchive/whitman-correspondence',
#    'url': 'https://api.github.com/repos/whitmanarchive/whitman-correspondence'},
#   'payload': {'action': 'closed',
#    'number': 14,
#    'pull_request': {'url': 'https://api.github.com/repos/whitmanarchive/whitman-correspondence/pulls/14',
#     'id': 1634848626,
#     'node_id': 'PR_kwDOAssz7c5hcc9y',
# ...
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'AadiDreams:main',
#      'ref': 'main',
#      'sha': '2c29b5f33f2cab197109501c8aae94906ed30349',
#      'user': {'login': 'AadiDreams',
#       'id': 120330808,
#       'node_id': 'U_kgDOBywaOA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/120330808?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AadiDreams',
#       'html_url': 'https://github.com/AadiDreams',
#       'followers_url': 'https://api.github.com/users/AadiDreams/followers',
#       'following_url': 'https://api.github.com/users/AadiDreams/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AadiDreams/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AadiDreams/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AadiDreams/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AadiDreams/orgs',
#       'repos_url': 'https://api.github.com/users/AadiDreams/repos',
#       'events_url': 'https://api.github.com/users/AadiDreams/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AadiDreams/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 717817492,
#       'node_id': 'R_kgDOKskGlA',
#       'name': 'CODSOFT',
#       'full_name': 'AadiDreams/CODSOFT',
#       'private': False,
#       'owner': {'login': 'AadiDreams',
#        'id': 120330808,
#        'node_id': 'U_kgDOBywaOA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/120330808?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AadiDreams',
#        'html_url': 'https://github.com/AadiDreams',
#        'followers_url': 'https://api.github.com/users/AadiDreams/followers',
#        'following_url': 'https://api.github.com/users/AadiDreams/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AadiDreams/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AadiDreams/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AadiDreams/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AadiDreams/orgs',
#        'repos_url': 'https://api.github.com/users/AadiDreams/repos',
#        'events_url': 'https://api.github.com/users/AadiDreams/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/AadiDreams/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/AadiDreams/CODSOFT',
#       'description': 'Repository for web development internship.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/AadiDreams/CODSOFT',
#       'forks_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/forks',
#       'keys_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/teams',
#       'hooks_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/hooks',
#       'issue_events_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/events',
#       'assignees_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/tags',
#       'blobs_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/languages',
#       'stargazers_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/stargazers',
#       'contributors_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/contributors',
#       'subscribers_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/subscribers',
#       'subscription_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/subscription',
#       'commits_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/merges',
#       'archive_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/downloads',
#       'issues_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/AadiDreams/CODSOFT/deployments',
#       'created_at': '2023-11-12T17:36:00Z',
#       'updated_at': '2023-11-13T18:18:41Z',
#       'pushed_at': '2023-12-09T19:02:23Z',
#       'git_url': 'git://github.com/AadiDreams/CODSOFT.git',
#       'ssh_url': 'git@github.com:AadiDreams/CODSOFT.git',
#       'clone_url': 'https://github.com/AadiDreams/CODSOFT.git',
#       'svn_url': 'https://github.com/AadiDreams/CODSOFT',
#       'homepage': None,
#       'size': 9677,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/AadiDreams/CODSOFT/pulls/8'},
#      'html': {'href': 'https://github.com/AadiDreams/CODSOFT/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/AadiDreams/CODSOFT/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/AadiDreams/CODSOFT/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/AadiDreams/CODSOFT/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/AadiDreams/CODSOFT/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/AadiDreams/CODSOFT/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/AadiDreams/CODSOFT/statuses/957d8e5666768b19892243837a6ca771f2fae323'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'AadiDreams',
#      'id': 120330808,
#      'node_id': 'U_kgDOBywaOA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/120330808?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/AadiDreams',
#      'html_url': 'https://github.com/AadiDreams',
#      'followers_url': 'https://api.github.com/users/AadiDreams/followers',
#      'following_url': 'https://api.github.com/users/AadiDreams/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/AadiDreams/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/AadiDreams/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/AadiDreams/subscriptions',
#      'organizations_url': 'https://api.github.com/users/AadiDreams/orgs',
#      'repos_url': 'https://api.github.com/users/AadiDreams/repos',
#      'events_url': 'https://api.github.com/users/AadiDreams/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/AadiDreams/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039775968',
#   'type': 'PushEvent',
#   'actor': {'id': 24660095,
#    'login': 'McTsts',
#    'display_login': 'McTsts',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/McTsts',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24660095?'},
#   'repo': {'id': 357348176,
#    'name': 'McTsts/Werewolves-Roles',
#    'url': 'https://api.github.com/repos/McTsts/Werewolves-Roles'},
#   'payload': {'repository_id': 357348176,
#    'push_id': 16210316114,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/formalize-everything',
#    'head': '05f786420cbad4467dbf9ee7a0de833d7bf89c23',
#    'before': '9d8b1fb391bbe42a180bb30c4049a1209af3628d',
#    'commits': [{'sha': '05f786420cbad4467dbf9ee7a0de833d7bf89c23',
#      'author': {'email': 'lpmctsts@gmail.com', 'name': 'Ts'},
#      'message': 'Update Solo Team Underworld',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/McTsts/Werewolves-Roles/commits/05f786420cbad4467dbf9ee7a0de833d7bf89c23'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039775948',
#   'type': 'PushEvent',
#   'actor': {'id': 96795933,
#    'login': '6ECCMEPTHIoIIJ',
#    'display_login': '6ECCMEPTHIoIIJ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/6ECCMEPTHIoIIJ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96795933?'},
#   'repo': {'id': 727309347,
#    'name': '6ECCMEPTHIoIIJ/Importal',
#    'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal'},
#   'payload': {'repository_id': 727309347,
#    'push_id': 16210316097,
#    'size': 10,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8debb622b89a3cc2b0aa939475992d7088ca627b',
#    'before': '54d6d92681ac3856732453d2f106589c29d53f1d',
#    'commits': [{'sha': 'ae49a16075dea1c5e487627ee3002bb26ca3a6be',
#      'author': {'email': 'vlad.vavilin73@gmail.com', 'name': 'Vladislav'},
#      'message': 'added game object class',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/ae49a16075dea1c5e487627ee3002bb26ca3a6be'},
#     {'sha': 'b614c99951666f41f0d284270585dd830a5c6a0b',
#      'author': {'email': 'vlad.vavilin73@gmail.com', 'name': 'Vladislav'},
#      'message': 'Game object interface',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/b614c99951666f41f0d284270585dd830a5c6a0b'},
#     {'sha': '220ef697691ca425a303fc62d7ef393a38327025',
#      'author': {'email': 'vlad.vavilin73@gmail.com', 'name': 'Vladislav'},
#      'message': 'GameComponent, GameObject, BehaviourComponent, Location',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/220ef697691ca425a303fc62d7ef393a38327025'},
#     {'sha': '7d7a9839f2dc9825bec16c02329ad3ef4a981353',
#      'author': {'email': 'vlad.vavilin73@gmail.com', 'name': 'Vladislav'},
#      'message': 'hasher fix',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/7d7a9839f2dc9825bec16c02329ad3ef4a981353'},
#     {'sha': '248a60a2ae9fdb16ca422c450069a81270bea801',
#      'author': {'email': 'vlad.vavilin73@gmail.com', 'name': 'Vladislav'},
#      'message': 'requires',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/248a60a2ae9fdb16ca422c450069a81270bea801'},
#     {'sha': '3fb0fe8f9df7d16bdd0bfd0ab559f5f3bccac9b1',
#      'author': {'email': 'vlad.vavilin73@gmail.com', 'name': 'Vladislav'},
#      'message': 'Sanya debil',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/3fb0fe8f9df7d16bdd0bfd0ab559f5f3bccac9b1'},
#     {'sha': 'c38f8130e00f8b096c3e1548b4b9e45d2fe166a1',
#      'author': {'email': 'vlad.vavilin73@gmail.com', 'name': 'Vladislav'},
#      'message': 'Transform',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/c38f8130e00f8b096c3e1548b4b9e45d2fe166a1'},
#     {'sha': '27bbc7d268c57f6264a8ea2b79e463786b08ccce',
#      'author': {'email': 'vlad.vavilin73@gmail.com', 'name': 'Vladislav'},
#      'message': 'tranfrom position fix)))',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/27bbc7d268c57f6264a8ea2b79e463786b08ccce'},
#     {'sha': '93847c08d434270ed47639348fb62b7570348e90',
#      'author': {'email': 'vlad.vavilin73@gmail.com', 'name': 'Vladislav'},
#      'message': 'transfrom constructor from position',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/93847c08d434270ed47639348fb62b7570348e90'},
#     {'sha': '8debb622b89a3cc2b0aa939475992d7088ca627b',
#      'author': {'email': 'shamraev.alexandr@outlook.com',
#       'name': '6ECCMEPTHIoIIJ'},
#      'message': 'merge',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/6ECCMEPTHIoIIJ/Importal/commits/8debb622b89a3cc2b0aa939475992d7088ca627b'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039775969',
#   'type': 'PushEvent',
#   'actor': {'id': 57485093,
#    'login': 'Vladislav1804vV',
#    'display_login': 'Vladislav1804vV',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Vladislav1804vV',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57485093?'},
#   'repo': {'id': 729063571,
#    'name': 'Vladislav1804vV/example_express_js',
#    'url': 'https://api.github.com/repos/Vladislav1804vV/example_express_js'},
#   'payload': {'repository_id': 729063571,
#    'push_id': 16210316111,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '683a7f059135ba2cf6407fa57d8f7412b92aecdc',
#    'before': 'b55ead742a84ddb309a0e26e3ca2526af277bff5',
#    'commits': [{'sha': '683a7f059135ba2cf6407fa57d8f7412b92aecdc',
#      'author': {'email': 'suhoverhov.vladislav1804@gmail.com',
#       'name': 'Vladislav'},
#      'message': 'Change vercel config',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Vladislav1804vV/example_express_js/commits/683a7f059135ba2cf6407fa57d8f7412b92aecdc'}]},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'},
#  {'id': '34039775947',
#   'type': 'CreateEvent',
#   'actor': {'id': 104513483,
#    'login': 'hassan-980',
#    'display_login': 'hassan-980',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hassan-980',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104513483?'},
#   'repo': {'id': 729606425,
#    'name': 'hassan-980/codestation.github.io',
#    'url': 'https://api.github.com/repos/hassan-980/codestation.github.io'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-12-09T19:02:24Z'}]

# %%
# Conteúdo bruto da resposta
## Caso queira obter a resposta bruta do soquete do servidor.

# %%
r = requests.get('https://api.github.com/events', stream=True)

# %%
r.raw

# %%
r.raw.read(10)
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03'

# %%
with open("arquivo", 'wb') as fd:
    for chunk in r.iter_content(chunk_size=128):
        fd.write(chunk)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# File c:\Users\phcer\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\response.py:445, in BaseHTTPResponse._decode(self, data, decode_content, flush_decoder)
#     444 if self._decoder:
# --> 445     data = self._decoder.decompress(data)
#     446     self._has_decoded_content = True
#
# File c:\Users\phcer\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\response.py:125, in GzipDecoder.decompress(self, data)
#     124 try:
# --> 125     ret += self._obj.decompress(data)
#     126 except zlib.error:
#
# error: Error -3 while decompressing data: incorrect header check
#
# The above exception was the direct cause of the following exception:
#
# DecodeError                               Traceback (most recent call last)
# File c:\Users\phcer\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
#
# File c:\Users\phcer\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\response.py:936, in HTTPResponse.stream(self, amt, decode_content)
#     935 while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 936     data = self.read(amt=amt, decode_content=decode_content)
#     938     if data:
#
# File c:\Users\phcer\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\response.py:900, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     898     return data
# --> 900 decoded_data = self._decode(data, decode_content, flush_decoder)
#     901 self._decoded_buffer.put(decoded_data)
#
# File c:\Users\phcer\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\response.py:449, in BaseHTTPResponse._decode(self, data, decode_content, flush_decoder)
#     448     content_encoding = self.headers.get("content-encoding", "").lower()
# --> 449     raise DecodeError(
#     450         "Received response with content-encoding: %s, but "
#     451         "failed to decode it." % content_encoding,
#     452         e,
#     453     ) from e
#     454 if flush_decoder:
#
# DecodeError: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))
#
# During handling of the above exception, another exception occurred:
#
# ContentDecodingError                      Traceback (most recent call last)
# c:\Users\phcer\Downloads\CienciadeDadosEspec-main\CienciadeDadosEspec-main\Projeto5\test\test_getter.ipynb Cell 22 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/phcer/Downloads/CienciadeDadosEspec-main/CienciadeDadosEspec-main/Projeto5/test/test_getter.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> with open("arquivo", 'wb') as fd:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/phcer/Downloads/CienciadeDadosEspec-main/CienciadeDadosEspec-main/Projeto5/test/test_getter.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a>     for chunk in r.iter_content(chunk_size=128):
#       <a href='vscode-notebook-cell:/c%3A/Users/phcer/Downloads/CienciadeDadosEspec-main/CienciadeDadosEspec-main/Projeto5/test/test_getter.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a>         fd.write(chunk)
#
# File c:\Users\phcer\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818     raise ChunkedEncodingError(e)
#     819 except DecodeError as e:
# --> 820     raise ContentDecodingError(e)
#     821 except ReadTimeoutError as e:
#     822     raise ConnectionError(e)
#
# ContentDecodingError: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))

# %% [markdown]
# # Abrindo arquivos com Python

# %%
arquivo2 = open("arquivo2.txt", 'w')
arquivo2.close()

# %%
casa = "A casa é bonita"

arquivo_casa = open("casa.txt", "w")

# %%
import io
arquivo_casa = io.StringIO(casa)

# %%
arquivo_casa.close()

# %%
with open("arquivo3.txt", 'w') as arquivo3:
    arquivo3.write("cansei.")

# %%
r = requests.get('https://api.github.com/events')
codigo_fonte = r.text

# %%
codigo_fonte
# Out:
# '[{"id":"34040001589","type":"WatchEvent","actor":{"id":114065226,"login":"Elena77777rrrf","display_login":"Elena77777rrrf","gravatar_id":"","url":"https://api.github.com/users/Elena77777rrrf","avatar_url":"https://avatars.githubusercontent.com/u/114065226?"},"repo":{"id":424697566,"name":"Uniswap/v4-core","url":"https://api.github.com/repos/Uniswap/v4-core"},"payload":{"action":"started"},"public":true,"created_at":"2023-12-09T19:29:39Z","org":{"id":36115574,"login":"Uniswap","gravatar_id":"","url":"https://api.github.com/orgs/Uniswap","avatar_url":"https://avatars.githubusercontent.com/u/36115574?"}},{"id":"34040001571","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":72368050,"name":"ocaml/dune","url":"https://api.github.com/repos/ocaml/dune"},"payload":{"repository_id":72368050,"push_id":16210444955,"size":1,"distinct_size":1,"ref":"refs/heads/gh-pages","head":"30041d89aff297be8590040030588fb9bf69edf3","before":"89a1ff02e3f4fb58d049582243f32b7b810e5f99","commits":[{"sha":"30041d89aff297be8590040030588fb9bf69edf3","author":{"email":"github@users.noreply.github.com","name":"github-action-benchmark"},"message":"add Synthetic Watch Benchmark (customSmallerIsBetter) benchmark result for d65ff8ca933aa6e8345091ea5257bf6219b34811","distinct":true,"url":"https://api.github.com/repos/ocaml/dune/commits/30041d89aff297be8590040030588fb9bf69edf3"}]},"public":true,"created_at":"2023-12-09T19:29:39Z","org":{"id":1841483,"login":"ocaml","gravatar_id":"","url":"https://api.github.com/orgs/ocaml","avatar_url":"https://avatars.githubusercontent.com/u/1841483?"}},{"id":"34040001581","type":"PushEvent","actor":{"id":16004891,"login":"Giammaria","display_login":"Giammaria","gravatar_id":"","url":"https://api.github.com/users/Giammaria","avatar_url":"https://avatars.githubusercontent.com/u/16004891?"},"repo":{"id":673940695,"name":"Giammaria/PublicFiles","url":"https://api.github.com/repos/Giammaria/PublicFiles"},"payload":{"repository_id":673940695,"push_id":16210444968,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"9ea415b027c57ab8858c2a2fd098e74757653517","before":"bc493271235466b8eb972713181a6e0ef5872a4c","commits":[{"sha":"9ea415b027c57ab8858c2a2fd098e74757653517","author":{"email":"your.email@example.com","name":"Your Name"},"message":"Update alphabet.json","distinct":true,"url":"https://api.github.com/repos/Giammaria/PublicFiles/commits/9ea415b027c57ab8858c2a2fd098e74757653517"}]},"public":true,"created_at":"2023-12-09T19:29:39Z"},{"id":"34040001574","type":"CreateEvent","actor":{"id":75031246,"login":"CosminManu","display_login":"CosminManu","gravatar_id":"","url":"https://api.github.com/users/CosminManu","avatar_url":"https://avatars.githubusercontent.com/u/75031246?"},"repo":{"id":729610894,"name":"CosminManu/eShoppingCart","url":"https://api.github.com/repos/CosminManu/eShoppingCart"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2023-12-09T19:29:39Z"},{"id":"34040001560","type":"PushEvent","actor":{"id":97512151,"login":"ananditasinghh","display_login":"ananditasinghh","gravatar_id":"","url":"https://api.github.com/users/ananditasinghh","avatar_url":"https://avatars.githubusercontent.com/u/97512151?"},"repo":{"id":728688520,"name":"ananditasinghh/portfolio01","url":"https://api.github.com/repos/ananditasinghh/portfolio01"},"payload":{"repository_id":728688520,"push_id":16210444951,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"0086b7ba4c71e1c2912e8beb92c3ef844df26dd3","before":"8e242a9e318b249fe940f4d7070a8ba43103fe94","commits":[{"sha":"0086b7ba4c71e1c2912e8beb92c3ef844df26dd3","author":{"email":"97512151+ananditasinghh@users.noreply.github.com","name":"Anandita Singh"},"message":"Update draft1.html","distinct":tr ...
