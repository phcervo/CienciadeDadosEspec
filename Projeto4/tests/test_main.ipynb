# %%
import test_es as es
import test_interpol as interpol

# %%
# Le as coordenadas
pontos=es.leitor_pontos()
f=interpol.ajusta_curva(pontos)

es.plota_grafico(pontos,f)
# Out:
# Digite o valor da coordenada x do 1ª ponto:  6
# Digite o valor da coordenada y do 1ª ponto:  11.6
# Deseja adicionar um novo ponto? (Digite 0 para Não) 1
# Digite o valor da coordenada x do 2ª ponto:  8
# Digite o valor da coordenada y do 2ª ponto:  21.5
# Deseja adicionar um novo ponto? (Digite 0 para Não) 1
# Digite o valor da coordenada x do 3ª ponto:  11
# Digite o valor da coordenada y do 3ª ponto:  35.6
# Deseja adicionar um novo ponto? (Digite 0 para Não) 13
# Digite o valor da coordenada x do 4ª ponto:  49.6
# Digite o valor da coordenada y do 4ª ponto:  108
# Deseja adicionar um novo ponto? (Digite 0 para Não) 0

# %%
pontos
# Out:
# [[5.0, 10.0, 9.0], [8.0, 12.0, 10.5]]
